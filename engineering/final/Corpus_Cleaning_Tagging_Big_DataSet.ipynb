# %%
import nltk
import pandas as pd
import matplotlib as plt
import re
import string
from pprint import pprint
from jsonmerge import merge

import pickle
import plotly

import pymongo
from pymongo import MongoClient
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from nltk.stem import PorterStemmer, SnowballStemmer, LancasterStemmer, WordNetLemmatizer

from warnings import filterwarnings
filterwarnings('ignore')

# %%
client = pymongo.MongoClient("mongodb+srv://wtyrna13:WkuLFvYJ7rUHQXu@cluster0.tpw7j.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.raw_data

# %%
db.collection_names()
# Out:
# ['for_class.raw_data', 'raw_data']

# %%
cursor = db.for_class.raw_data.find()
all_data = list(cursor)

# %%
len(all_data)
# Out:
# 3

# %%
big_df1 = pd.DataFrame(all_data[0]['id'], index=[0])
big_df2 = pd.DataFrame(all_data[0]['body'], index=[0])
big_df3 = pd.DataFrame(all_data[0]['dates'], index=[0])

df1_transposed = big_df1.T # or df1.transpose()
df2_transposed = big_df2.T
df3_transposed = big_df3.T

data1 = pd.concat([df1_transposed, df2_transposed,df3_transposed], axis=1)
data1.rename(columns={ data1.columns[0]: "id", data1.columns[1]: "text",data1.columns[2]: "timestamp"  }, inplace = True)

# %%
data1
# Out:
#       timestamp                                          timestamp  \
# 0        q6fxy0                                              Rapé?
# 1        q6fxy0  Rapé is not yopo \n\nRapé basically isn’t psyc...
# 2        q6fxy0  Yopo?  Be careful!  Research heavily.  I belie...
# 3        q6fxy0  Rapé is a mixture of tobacco and other plants....
# 4        q6fxy0            Wow ok then sortable DMT, sounds badass
# ...         ...                                                ...
# 28938    o5w639  >Benzos are my fav in moderation so something ...
# 28939    o5w639                       Clomethiazole but be careful
# 28940    o5w639  I’ve never taken any RC’s before (knowingly🤣) ...
# 28941    o5wdsm  You may have just gotten me back into recreati...
# 28942    o5wdsm                                   Sounds like fun.
#
#                  timestamp
# 0      2021-10-12 02:32:00
# 1      2021-10-12 02:32:00
# 2      2021-10-12 02:32:00
# 3      2021-10-12 02:32:00
# 4      2021-10-12 02:32:00
# ...                    ...
# 28938  2021-06-22 16:14:15
# 28939  2021-06-22 16:14:15
# 28940  2021-06-22 16:14:15
# 28941  2021-06-22 16:23:54
# 28942  2021-06-22 16:23:54
#
# [28943 rows x 3 columns]

# %%
big_df1 = pd.DataFrame(all_data[1]['id'], index=[0])
big_df2 = pd.DataFrame(all_data[1]['body'], index=[0])
big_df3 = pd.DataFrame(all_data[1]['dates'], index=[0])

df1_transposed = big_df1.T # or df1.transpose()
df2_transposed = big_df2.T
df3_transposed = big_df3.T

data2 = pd.concat([df1_transposed, df2_transposed,df3_transposed], axis=1)
data2.rename(columns={ data2.columns[0]: "id", data2.columns[1]: "text",data2.columns[2]: "timestamp"  }, inplace = True)

# %%
big_df1 = pd.DataFrame(all_data[2]['id'], index=[0])
big_df2 = pd.DataFrame(all_data[2]['body'], index=[0])
big_df3 = pd.DataFrame(all_data[2]['dates'], index=[0])

df1_transposed = big_df1.T # or df1.transpose()
df2_transposed = big_df2.T
df3_transposed = big_df3.T

data3 = pd.concat([df1_transposed, df2_transposed,df3_transposed], axis=1)
data3.rename(columns={ data3.columns[0]: "id", data3.columns[1]: "text",data3.columns[2]: "timestamp"  }, inplace = True)

# %%
data = pd.concat([data1, data2,data2])

# %%
data.columns = ['id', 'text', 'timestamp']

# %%
data
# Out:
#            id                                               text  \
# 0      q6fxy0                                              Rapé?
# 1      q6fxy0  Rapé is not yopo \n\nRapé basically isn’t psyc...
# 2      q6fxy0  Yopo?  Be careful!  Research heavily.  I belie...
# 3      q6fxy0  Rapé is a mixture of tobacco and other plants....
# 4      q6fxy0            Wow ok then sortable DMT, sounds badass
# ...       ...                                                ...
# 57881  lkq2iy  Boofing 4-AcO-DMT is vastly superior to eating...
# 57882  lkq2iy  Mushrooms all the way. They ARE different, alt...
# 57883  lkq2iy  I don’t mean 4-ACO-DMT vs 4-HO-DMT aka Psiloci...
# 57884  lkqec1  Etiz vapes just to note\n\nMy bets on right be...
# 57885  lkqec1  Hi, I got a delivery of 0.5g etizolam and 0.5g...
#
#                  timestamp
# 0      2021-10-12 02:32:00
# 1      2021-10-12 02:32:00
# 2      2021-10-12 02:32:00
# 3      2021-10-12 02:32:00
# 4      2021-10-12 02:32:00
# ...                    ...
# 57881  2021-02-15 18:23:58
# 57882  2021-02-15 18:23:58
# 57883  2021-02-15 18:23:58
# 57884  2021-02-15 18:39:46
# 57885  2021-02-15 18:39:46
#
# [86829 rows x 3 columns]

# %%
split_text = []
for i in data.text:
    text = str(i).split()
    split_text.append(text)

# %%
data['split_text'] = split_text

# %%
counter = []
for i in data.split_text:
    counter.append(len(i))

# %%
data['counter'] = counter

# %%
mask = (data['counter'] > 100)

# %%
data2 = data[mask]

# %%
data2
# Out:
#            id                                               text  \
# 20     q6hjm6  I don't have much experience with pg solutions...
# 28     q6igkm  4F-MPH (4-flouromethylphenidate), while not ha...
# 34     q6k9vd  It seems like an accurate name for what it is....
# 35     q6k9vd  I think as it stands now people take the defin...
# 39     q6k9vd  I've started to have some pretty hot-takes on ...
# ...       ...                                                ...
# 57864  lko5k0  Imo the DNM is perfect, escrow, PGP and eBay s...
# 57869  lko5k0  Not that I “prefer”. My goal is to try everyth...
# 57873  lko5k0  Hey everyone, so I’m wondering why you all pre...
# 57875  lko5vp  Hi, so i've never turned anything into freebas...
# 57885  lkqec1  Hi, I got a delivery of 0.5g etizolam and 0.5g...
#
#                  timestamp                                         split_text  \
# 20     2021-10-12 04:28:41  [I, don't, have, much, experience, with, pg, s...
# 28     2021-10-12 05:38:03  [4F-MPH, (4-flouromethylphenidate),, while, no...
# 34     2021-10-12 07:42:56  [It, seems, like, an, accurate, name, for, wha...
# 35     2021-10-12 07:42:56  [I, think, as, it, stands, now, people, take, ...
# 39     2021-10-12 07:42:56  [I've, started, to, have, some, pretty, hot-ta...
# ...                    ...                                                ...
# 57864  2021-02-15 16:52:07  [Imo, the, DNM, is, perfect,, escrow,, PGP, an...
# 57869  2021-02-15 16:52:07  [Not, that, I, “prefer”., My, goal, is, to, tr...
# 57873  2021-02-15 16:52:07  [Hey, everyone,, so, I’m, wondering, why, you,...
# 57875  2021-02-15 16:52:33  [Hi,, so, i've, never, turned, anything, into,...
# 57885  2021-02-15 18:39:46  [Hi,, I, got, a, delivery, of, 0.5g, etizolam,...
#
#        counter
# 20         137
# 28         251
# 34         114
# 35         105
# 39         253
# ...        ...
# 57864      182
# 57869      160
# 57873      154
# 57875      143
# 57885      124
#
# [10075 rows x 5 columns]

# %%
#### make lowercase and remove punctuation

alphanumeric = lambda x: re.sub('\w*\d\w*', ' ', x)
punc_lower = lambda x: re.sub('[%s]' % re.escape(string.punctuation), ' ', x.lower())

data2['text'] = data2.text.map(alphanumeric).map(punc_lower)

# %%
def make_corpus(x):
    a_file = open(x, "r")
    corpus = [s.strip() for s in a_file.readlines()]
    a_file.close()
    return corpus

# %%
corpus1 = make_corpus('stop_words_english.txt')
corpus2 = make_corpus("google-10000-english-usa.txt")
big_corpus = corpus1 + corpus2

# %%
stemmer = SnowballStemmer('english')

# %%
####create initial filter, apply stemming

filtered = []
for i in data2.text:
    new_data = i.split()
    post_filter = []
    for i in new_data:
        if i not in corpus1:
            i = stemmer.stem(i)        
            if i not in corpus2:
                post_filter.append(i)
    post_filter = ' '.join(post_filter)
    filtered.append(post_filter)
data2['general_words_removed'] = filtered

# %%
drug_corpus_clean = ['amphetamine', 'clonazolam', 'dopamine', 'methylphenidate', 'bromazolam', 'triptamine', 'dmt', 'mxe', 'fxe', 'flubromazolam',
 'triazolam', 'flualprazolam', 'arylcyclohexylamine', 'acetone', 'chloride', 'etizolam', 'alprazolam',
 'dinotrogen', 'dpt', 'dck', 'bromazepam', 'lorazepam', 'trazodone', 'mirtazapine', 'ketamine', 'klonopin', 'propranolol',
 'fluclotizolam', 'diclazepam', 'norflurazepam', 'quetiapine', 'xan', 'hydrochloride', 'aplrazolam', 'phenethylamine', 'bretazenil', 'rilmazafone', 'pyrazolam', 'emoxypine', 'fasoracetam', 'mda', 'tyrosine', 'diazepam', 'phenylpiracetam', 'pvp', 'flunitrazolam', 'cyclazodone',
 'thc', 'dexamphetamine', 'benzene', 'piracetam', 'benzodiazepine', 'diazepine', 'tryptamine', 'diclaz',
 'metizolam', 'flubrotizolam', 'mescaline', 'hydroxytryptamine', 'dimethyltryptamine', 'clonazepam', 'clonzolam', 'doxylamine', 'diphenydramine',
 'ket', 'allylescaline', 'phenylethylamine', 'oxy', 'nitrazolam', 'clonozolam', 'dopamine',
 'etazene', 'methylamphetamine', 'phenidate', 'mth', 'dextroamphetamine', 'midazolam', 'methamphetamine',
 'fluoroamphetamine', 'ethyltryptamine', 'ethylamine', 'flouromethamphetamine', 'methoxetamine', 'cyclaz', 'zylofuramine', 'cypenamine', 'ephenidine', 'ketamine', 'flumazenil', 'xtc',
 'monoamine', 'methallylescaline', 'methallyescaline', 'propanolol', 'tapentadol', 'esketamine', 'sine', 'isopropylphenidate', 'ethylphenidate', 'diphenhydramine', 'metodesnitazene',
 'fluonitazene', 'tiletamine', 'flubromzolam', 'isotonitazene', 'proppranolol', 'racetam', 'desoxymethoxetamine', 'imidazenil',
 'isopropyphenidate', 'propylphenidate', 'fluoromethylphenidate', 'lisdexamphetamine', 'isoproscaline',
 'isopropoxyphenethylamine', 'mhp', 'lisdexamfetamine', 'flourodeschloroketamine', 'sulbutiamine', 'trpytamine', 'methiopropamine', 'methalyescaline',
 'flurazepam', 'olanzapine', 'dizocilpine', 'nimetazepam', 'methylenedioxymethamphetamine', 'etonitazene',
 'lormetazepam', 'flunitrazepam', 'dxe', 'temazepam', 'oxazepam', 'ephinidine', 'thiamine', 'tryosine', 'bromozolam', 'isopropylphenidine',
 'chloroephenidine', 'hydroxymetamine', 'pcm', 'methoxyketamine', 'norketamine', 'cyclopropylmescaline', 'dichloromescaline', 'dibromomescaline', 'hodgkinsine',
 'phenazepam', 'brotizolam', 'hearthstone', 'methallallylescaline', 'deoxymethoxetamine', 'zolam', 'methoxpropamine',
 'metilphenidate', 'deschloroketamine','itonitazene']

additional_drug_terms = ['opioid','tramadol','tramadol','dopamin','vyvans','oxycodon','dsmt','gabapentin','memantin','benzo',
                         'opiat','kpin','psilocybin','fdck','mxipr','hexen','redos','arylcyclohexylamin','odsmt','methadon','dipt',
                        'morphin','etazen','eutylon','suboxon','glycol','mxpr','dmxe','shroom','isom','amphetamin','methylphenid','mapb',
                        'kratom','ethyl','coke','adderall','etiz','meth','heroin','mdma','cannabinoid','benzos','phenibut','ethanol','cathinone',
                        'cathinon','gram','ketamin']

misc_terms = ['researchchem','wiki','https','subreddit','psychonautwiki','clam','pyro','adhd','doses','didn',
              'don','stims','reddit','doesn','woudln','don','taper','honestly','solut','experience','effect','experi',
             'minut','peopl','daili','pretti','sleep','question','reddit',]

# %%
additional_terms = set(drug_corpus_clean + additional_drug_terms + misc_terms)

# %%
drug_corpus = set(drug_corpus_clean + additional_drug_terms)

# %%
filtered2 = []
for i in data2.general_words_removed:
    new_data = i.split()
    post_filter = []
    for i in new_data:
        if len(i) > 4 and i not in additional_terms:
            post_filter.append(i)
    post_filter = ' '.join(post_filter)
    filtered2.append(post_filter)  
data2['drugsremoved'] = filtered2

# %%
data = data2

# %%
tf_vectorizer = CountVectorizer(strip_accents = 'unicode',
                                stop_words = 'english',
                                lowercase = True,
                                token_pattern = r'\b[a-zA-Z]{3,}\b',
                                max_df = 4, #ignore terms that appear in more than X% of the document 
                                min_df = 0)  #ignore terms that appear in less than X documents
dtm_tf = tf_vectorizer.fit_transform(data.drugsremoved)

# %%
tfidf_vectorizer = TfidfVectorizer(**tf_vectorizer.get_params())
dtm_tfidf = tfidf_vectorizer.fit_transform(data.drugsremoved)

# %%
# load the model from disk
loaded_model = pickle.load(open('finalized_model.sav', 'rb'))

# %%
ex_label = [e[:30]+"..." for e in data.drugsremoved]
doc_word = tf_vectorizer.fit_transform(data.drugsremoved)
pd.DataFrame(doc_word.toarray(), index=ex_label, columns=tf_vectorizer.get_feature_names()).head(10).reset_index(drop=True, inplace=True)

# %%
doc_topic = loaded_model.fit_transform(doc_word)

# %%
topics = pd.DataFrame(doc_topic.round(5),
             index = ex_label,
             columns = ["Psycadelic","Euphoric",'Negative','Dangerous'])

# %%
maxValueIndexObj = topics.idxmax(axis=1)
topics['effect'] = maxValueIndexObj
topics = topics.reset_index()

# %%
data
# Out:
#            id                                               text  \
# 20     q6hjm6  i don t have much experience with pg solutions...
# 28     q6igkm    mph    flouromethylphenidate   while not hav...
# 34     q6k9vd  it seems like an accurate name for what it is ...
# 35     q6k9vd  i think as it stands now people take the defin...
# 39     q6k9vd  i ve started to have some pretty hot takes on ...
# ...       ...                                                ...
# 57864  lko5k0  imo the dnm is perfect  escrow  pgp and ebay s...
# 57869  lko5k0  not that i “prefer”  my goal is to try everyth...
# 57873  lko5k0  hey everyone  so i’m wondering why you all pre...
# 57875  lko5vp  hi  so i ve never turned anything into freebas...
# 57885  lkqec1  hi  i got a delivery of     etizolam and     e...
#
#                  timestamp                                         split_text  \
# 20     2021-10-12 04:28:41  [I, don't, have, much, experience, with, pg, s...
# 28     2021-10-12 05:38:03  [4F-MPH, (4-flouromethylphenidate),, while, no...
# 34     2021-10-12 07:42:56  [It, seems, like, an, accurate, name, for, wha...
# 35     2021-10-12 07:42:56  [I, think, as, it, stands, now, people, take, ...
# 39     2021-10-12 07:42:56  [I've, started, to, have, some, pretty, hot-ta...
# ...                    ...                                                ...
# 57864  2021-02-15 16:52:07  [Imo, the, DNM, is, perfect,, escrow,, PGP, an...
# 57869  2021-02-15 16:52:07  [Not, that, I, “prefer”., My, goal, is, to, tr...
# 57873  2021-02-15 16:52:07  [Hey, everyone,, so, I’m, wondering, why, you,...
# 57875  2021-02-15 16:52:33  [Hi,, so, i've, never, turned, anything, into,...
# 57885  2021-02-15 18:39:46  [Hi,, I, got, a, delivery, of, 0.5g, etizolam,...
#
#        counter                              general_words_removed  \
# 20         137  experi solut chemic fulli dissolv chemic etiz ...
# 28         251  flouromethylphenid durat numb studi cocain med...
# 34         114  accur practic reduc chanc caus impli reduc sem...
# 35         105  peopl definit reduct reduct advic peopl harass...
# 39         253  pretti agre promot complet decrimin stigma add...
# ...        ...                                                ...
# 57864      182  imo dnm escrow carri verifi natur encrypt sign...
# 57869      160  “prefer” varieti dpt fav eth lad hypocrit lsd ...
# 57873      154  i'm rcs substanc i'm legitimaci clearnet aco r...
# 57875      143  freebas dmt nexus crystallis techniqu tini vap...
# 57885      124  deliveri etizolam etazen ofc didn messag etizo...
#
#                                             drugsremoved
# 20     chemic fulli dissolv chemic multipl sublingu f...
# 28     flouromethylphenid durat studi cocain medic fl...
# 34     accur practic reduc chanc impli reduc semant s...
# 35     definit reduct reduct advic harass plenti smar...
# 39     promot complet decrimin stigma addict realiz s...
# ...                                                  ...
# 57864  escrow carri verifi natur encrypt signatur bea...
# 57869  “prefer” varieti hypocrit solvent decid delir ...
# 57873  substanc legitimaci clearnet reliabl dismay do...
# 57875  freebas nexus crystallis techniqu chanc concen...
# 57885  deliveri messag shini scali shini chemic ident...
#
# [10075 rows x 7 columns]

# %%
effects = []
for i in topics.effect:
    effects.append(i)
data['effect'] = effects

# %%
data
# Out:
#            id                                               text  \
# 20     q6hjm6  i don t have much experience with pg solutions...
# 28     q6igkm    mph    flouromethylphenidate   while not hav...
# 34     q6k9vd  it seems like an accurate name for what it is ...
# 35     q6k9vd  i think as it stands now people take the defin...
# 39     q6k9vd  i ve started to have some pretty hot takes on ...
# ...       ...                                                ...
# 57864  lko5k0  imo the dnm is perfect  escrow  pgp and ebay s...
# 57869  lko5k0  not that i “prefer”  my goal is to try everyth...
# 57873  lko5k0  hey everyone  so i’m wondering why you all pre...
# 57875  lko5vp  hi  so i ve never turned anything into freebas...
# 57885  lkqec1  hi  i got a delivery of     etizolam and     e...
#
#                  timestamp                                         split_text  \
# 20     2021-10-12 04:28:41  [I, don't, have, much, experience, with, pg, s...
# 28     2021-10-12 05:38:03  [4F-MPH, (4-flouromethylphenidate),, while, no...
# 34     2021-10-12 07:42:56  [It, seems, like, an, accurate, name, for, wha...
# 35     2021-10-12 07:42:56  [I, think, as, it, stands, now, people, take, ...
# 39     2021-10-12 07:42:56  [I've, started, to, have, some, pretty, hot-ta...
# ...                    ...                                                ...
# 57864  2021-02-15 16:52:07  [Imo, the, DNM, is, perfect,, escrow,, PGP, an...
# 57869  2021-02-15 16:52:07  [Not, that, I, “prefer”., My, goal, is, to, tr...
# 57873  2021-02-15 16:52:07  [Hey, everyone,, so, I’m, wondering, why, you,...
# 57875  2021-02-15 16:52:33  [Hi,, so, i've, never, turned, anything, into,...
# 57885  2021-02-15 18:39:46  [Hi,, I, got, a, delivery, of, 0.5g, etizolam,...
#
#        counter                              general_words_removed  \
# 20         137  experi solut chemic fulli dissolv chemic etiz ...
# 28         251  flouromethylphenid durat numb studi cocain med...
# 34         114  accur practic reduc chanc caus impli reduc sem...
# 35         105  peopl definit reduct reduct advic peopl harass...
# 39         253  pretti agre promot complet decrimin stigma add...
# ...        ...                                                ...
# 57864      182  imo dnm escrow carri verifi natur encrypt sign...
# 57869      160  “prefer” varieti dpt fav eth lad hypocrit lsd ...
# 57873      154  i'm rcs substanc i'm legitimaci clearnet aco r...
# 57875      143  freebas dmt nexus crystallis techniqu tini vap...
# 57885      124  deliveri etizolam etazen ofc didn messag etizo...
#
#                                             drugsremoved      effect
# 20     chemic fulli dissolv chemic multipl sublingu f...  Psycadelic
# 28     flouromethylphenid durat studi cocain medic fl...  Psycadelic
# 34     accur practic reduc chanc impli reduc semant s...  Psycadelic
# 35     definit reduct reduct advic harass plenti smar...    Euphoric
# 39     promot complet decrimin stigma addict realiz s...  Psycadelic
# ...                                                  ...         ...
# 57864  escrow carri verifi natur encrypt signatur bea...   Dangerous
# 57869  “prefer” varieti hypocrit solvent decid delir ...    Negative
# 57873  substanc legitimaci clearnet reliabl dismay do...    Euphoric
# 57875  freebas nexus crystallis techniqu chanc concen...  Psycadelic
# 57885  deliveri messag shini scali shini chemic ident...  Psycadelic
#
# [10075 rows x 8 columns]

# %%
from collections import OrderedDict
def remove_duplicate(s): 
    new_list = []
    i = ",".join(OrderedDict.fromkeys(s))
    i = i.split(',')
    for i in i:
        new_list.append(i.replace('"', ""))
    return new_list

# %%
drug_terms = []
for i in data.text:
    new_data = i.split()
    post_filter = []
    for i in new_data:
        if i in drug_corpus:
            post_filter.append(i)
            post_ = remove_duplicate(post_filter)
    post_filter = ' '.join(post_)
    drug_terms.append(post_filter)

# %%
drug_terms
# Out:
# ['etiz ethanol diclazepam',
#  'fluoromethylphenidate methylphenidate dopamine coke',
#  'fluoromethylphenidate methylphenidate dopamine coke',
#  'fluoromethylphenidate methylphenidate dopamine coke',
#  'fluoromethylphenidate methylphenidate dopamine coke',
#  'fluoromethylphenidate methylphenidate dopamine coke',
#  'methylphenidate',
#  'mdma phenethylamine',
#  'mdma phenethylamine',
#  'mdma phenethylamine',
#  'mdma phenethylamine',
#  'mapb',
#  'etizolam benzo etiz',
#  'phenibut gabapentin benzos',
#  'pvp dmt',
#  'opioid mxipr mdma',
#  'kratom',
#  'opioid',
#  'opioid',
#  'opioid',
#  'dopamine opioid',
#  'mirtazapine benzos gabapentin',
#  'benzos etiz',
#  'benzos etiz',
#  'benzos etiz',
#  'etizolam flualprazolam clonazolam bromazolam pyrazolam',
#  'etizolam flualprazolam clonazolam bromazolam pyrazolam',
#  'etizolam bromazolam etiz trazodone diclazepam benzo clonazolam diclaz',
#  'amphetamine',
#  'heroin mdma mda mapb tryptamine',
#  'heroin mdma mda mapb tryptamine',
#  'heroin mdma mda mapb tryptamine',
#  'etizolam meth',
#  'opioid phenibut piracetam',
#  'alprazolam dmt mdma mda amphetamine',
#  'dopamine',
#  'dck hydrochloride',
#  'dmt',
#  'dmt',
#  'dmt',
#  'mdma',
#  'mdma',
#  'ketamine ket',
#  'etiz',
#  'benzos',
#  'etizolam benzo benzos',
#  'benzos etiz',
#  'hexen coke',
#  'mapb',
#  'dck ketamine fdck cathinone meth mda benzos',
#  'dck ketamine fdck cathinone meth mda benzos',
#  'mdma meth',
#  'mdma meth',
#  'mdma',
#  'benzos',
#  'flubromazolam odsmt thc',
#  'mdma amphetamine dopamine cathinone',
#  'glycol benzos',
#  'clonazolam glycol',
#  'phenibut benzos',
#  'phenibut',
#  'mapb',
#  'mapb',
#  'mapb',
#  'psilocybin',
#  'mdma ketamine meth',
#  'cathinone monoamine dopamine',
#  'coke',
#  'coke',
#  'coke',
#  'benzo bromazolam',
#  'klonopin',
#  'klonopin',
#  'hexen coke meth',
#  'hexen dopamine coke',
#  'mapb',
#  'mapb',
#  'mapb',
#  'psilocybin',
#  'coke meth benzos heroin dmt',
#  'kratom benzos',
#  'tryptamine adderall opioid',
#  'tryptamine',
#  'tryptamine',
#  'psilocybin arylcyclohexylamine dck dimethyltryptamine dmt tryptamine',
#  'psilocybin phenethylamine monoamine methylenedioxymethamphetamine mdma dopamine methamphetamine amphetamine',
#  'benzos clonazepam alprazolam diazepam lorazepam midazolam oxazepam temazepam',
#  'meth',
#  'phenethylamine',
#  'phenethylamine',
#  'phenethylamine',
#  'benzos oxy bromazolam benzo',
#  'etizolam benzo bretazenil odsmt',
#  'benzos mdma',
#  'benzo odsmt bretazenil rilmazafone',
#  'amphetamine chloride',
#  'amphetamine phenethylamine',
#  'amphetamine phenethylamine',
#  'heroin',
#  'heroin',
#  'heroin',
#  'hexen',
#  'meth',
#  'bromazolam',
#  'ketamine',
#  'clonazolam',
#  'dsmt etazene',
#  'odsmt opioid benzos',
#  'opioid heroin',
#  'opioid benzo oxy heroin etazene',
#  'opioid dsmt fluonitazene',
#  'clonazolam etiz benzo kpin',
#  'benzo etiz alprazolam clonazolam benzos',
#  'benzo etiz alprazolam clonazolam benzos',
#  'meth',
#  'meth',
#  'meth',
#  'meth',
#  'meth',
#  'meth',
#  'thc',
#  'mapb mdma',
#  'dck',
#  'bromazolam benzos clonazolam etizolam fluclotizolam',
#  'etiz bromazolam clonazolam',
#  'etizolam benzo',
#  'benzo benzos gabapentin kratom',
#  'kratom phenibut benzo',
#  'kratom phenibut benzos bromazolam clonazolam flubromazolam benzo',
#  'flualprazolam benzo',
#  'dmxe dck mxpr pcm',
#  'dmxe dck mxpr pcm',
#  'methamphetamine',
#  'phenibut kratom odsmt',
#  'phenibut kratom odsmt',
#  'phenibut kratom odsmt',
#  'phenibut kratom odsmt',
#  'phenibut kratom odsmt',
#  'phenibut kratom odsmt',
#  'phenibut kratom odsmt',
#  'phenibut kratom odsmt',
#  'phenibut kratom odsmt',
#  'phenibut kratom odsmt',
#  'phenibut kratom odsmt',
#  'phenibut kratom odsmt',
#  'phenibut kratom odsmt',
#  'phenibut kratom odsmt',
#  'ketamine',
#  'heroin benzos clonazepam alprazolam diazepam lorazepam midazolam oxazepam temazepam',
#  'etizolam benzos bromazolam',
#  'etizolam benzos bromazolam',
#  'etizolam benzos bromazolam',
#  'etizolam benzos bromazolam',
#  'etizolam benzos bromazolam',
#  'dopamine meth',
#  'etizolam adderall',
#  'etizolam adderall',
#  'benzos',
#  'amphetamine dextroamphetamine',
#  'adderall diclazepam',
#  'ketamine mxipr mdma',
#  'ketamine',
#  'ketamine',
#  'ketamine',
#  'ketamine',
#  'ketamine',
#  'ketamine',
#  'mdma coke',
#  'mdma coke',
#  'mdma dmt',
#  'shroom dmt',
#  'fdck dmt mapb amphetamine lorazepam dck deschloroketamine diphenhydramine dimethyltryptamine ketamine mda mdma mxe psilocybin diazepam alprazolam',
#  'amphetamine adderall lisdexamphetamine dextroamphetamine pvp methylamphetamine methylphenidate dmt dpt psilocybin mxipr ephenidine deschloroketamine fdck ketamine mdma mapb kratom tramadol dsmt alprazolam phenibut clonazepam klonopin diazepam lorazepam etizolam gabapentin flualprazolam pyrazolam',
#  'dmt adderall lisdexamphetamine methylphenidate kratom tramadol clonazepam gabapentin phenibut',
#  'heroin dmt methamphetamine alprazolam lorazepam clonazolam mda mdma mescaline ketamine thc gabapentin tramadol amphetamine',
#  'mescaline',
#  'arylcyclohexylamine thc ketamine opioid',
#  'benzos',
#  'benzo etizolam benzos bromazolam pyrazolam',
#  'coke meth',
#  'coke meth',
#  'mdma',
#  'coke mdma',
#  'benzo opioid benzos',
#  'benzo opioid benzos',
#  'meth',
#  'dmt dpt mdma mda mescaline thc ketamine',
#  'dmt dpt mdma mda mescaline thc ketamine',
#  'dmt dpt mdma mda mescaline thc ketamine',
#  'mdma',
#  'coke',
#  'arylcyclohexylamine opioid',
#  'benzos',
#  'benzo',
#  'adderall kratom heroin',
#  'adderall kratom heroin',
#  'adderall kratom heroin',
#  'adderall kratom heroin',
#  'adderall methylphenidate',
#  'benzos',
#  'benzos',
#  'meth gram amphetamine methamphetamine',
#  'meth gram amphetamine methamphetamine',
#  'ethyl',
#  'ethyl',
#  'ketamine mdma mda ket dmt dpt dipt mescaline',
#  'gram coke adderall benzos',
#  'gram coke adderall benzos',
#  'benzos',
#  'gram mxipr tiletamine ketamine benzos',
#  'gram mxipr tiletamine ketamine benzos',
#  'gram mxipr tiletamine ketamine benzos',
#  'gram mxipr tiletamine ketamine benzos',
#  'xtc mdma ketamine coke benzo',
#  'xtc mdma ketamine coke benzo',
#  'dmt meth',
#  'odsmt kratom dck opioid benzos',
#  'odsmt kratom dck opioid benzos',
#  'odsmt kratom dck opioid benzos',
#  'dpt heroin meth mdma',
#  'mapb ketamine',
#  'mapb ketamine',
#  'mapb ketamine',
#  'mapb ketamine',
#  'heroin',
#  'heroin',
#  'gram',
#  'ethanol benzos',
#  'ethanol',
#  'methylphenidate',
#  'thc',
#  'thc',
#  'thc',
#  'thc',
#  'coke dopamine hexen',
#  'mapb tryptamine dopamine mdma',
#  'mdma',
#  'mdma',
#  'adderall',
#  'meth dopamin',
#  'mdma adderall amphetamine',
#  'mdma adderall amphetamine',
#  'mdma adderall amphetamine',
#  'mdma adderall amphetamine',
#  'mdma adderall amphetamine',
#  'mdma adderall amphetamine',
#  'shroom benzos',
#  'diclazepam flualprazolam',
#  'etizolam etiz',
#  'etizolam etiz',
#  'etizolam etiz',
#  'etizolam etiz',
#  'benzos quetiapine',
#  'benzo',
#  'benzos',
#  'benzo adderall',
#  'amphetamine opioid',
#  'etiz benzo',
#  'amphetamine mescaline',
#  'mescaline',
#  'clonazolam diclazepam benzos benzo alprazolam meth',
#  'phenibut pyrazolam emoxypine benzos benzo fasoracetam',
#  'phenibut pyrazolam emoxypine benzos benzo fasoracetam',
#  'pyrazolam',
#  'ketamine mdma phenibut',
#  'mdma mapb dck',
#  'dck benzo',
#  'mdma mapb mda',
#  'tyrosine',
#  'diclazepam',
#  'etiz benzo benzos',
#  'diclazepam diazepam benzo odsmt tramadol',
#  'diclazepam diazepam benzo odsmt tramadol',
#  'diclazepam diazepam benzo odsmt tramadol',
#  'diclazepam diazepam benzo odsmt tramadol',
#  'heroin meth pvp',
#  'heroin meth pvp',
#  'benzo midazolam flunitrazolam benzos benzodiazepine diazepam diclazepam',
#  'dmt',
#  'benzo phenibut phenylpiracetam amphetamine dopamine',
#  'gabapentin',
#  'gabapentin',
#  'gabapentin',
#  'hydrochloride',
#  'mdma heroin',
#  'flualprazolam benzo',
#  'coke dopamine',
#  'hexen mdma',
#  'hexen mdma',
#  'benzodiazepine benzo ketamine',
#  'cypenamine cyclazodone',
#  'benzos flunitrazolam bromazolam',
#  'clonazolam ethanol',
#  'clonazolam ethanol',
#  'meth',
#  'meth',
#  'meth',
#  'etiz',
#  'phenidate cyclazodone meth',
#  'phenidate cyclazodone meth',
#  'phenidate cyclazodone meth',
#  'phenidate cyclazodone meth',
#  'phenidate cyclazodone meth',
#  'dck mxpr',
#  'gram etizolam benzos pyrazolam',
#  'mxipr',
#  'etizolam etiz',
#  'flunitrazepam lorazepam triazolam diazepam etizolam clonazolam',
#  'flunitrazepam lorazepam triazolam diazepam etizolam clonazolam',
#  'flunitrazepam lorazepam triazolam diazepam etizolam clonazolam',
#  'flunitrazepam lorazepam triazolam diazepam etizolam clonazolam',
#  'amphetamine mdma',
#  'heroin adderall',
#  'dmxe ketamine ket',
#  'dmxe ketamine ket',
#  'opioid',
#  'heroin',
#  'heroin',
#  'heroin',
#  'heroin',
#  'heroin',
#  'heroin',
#  'heroin',
#  'ketamine',
#  'ketamine',
#  'diazepam benzos coke',
#  'heroin diazepam ketamine dmt mdma benzo',
#  'heroin diazepam ketamine dmt mdma benzo',
#  'heroin diazepam ketamine dmt mdma benzo',
#  'heroin diazepam ketamine dmt mdma benzo',
#  'heroin diazepam ketamine dmt mdma benzo',
#  'benzo',
#  'benzo',
#  'mapb fluoroamphetamine dopamine',
#  'meth',
#  'meth',
#  'odsmt',
#  'benzo dextroamphetamine adderall diazepam alprazolam',
#  'mescaline methallylescaline mda',
#  'mdma adderall amphetamine thc dmt heroin ketamine mescaline methamphetamine mxe methylphenidate alprazolam',
#  'mdma adderall amphetamine thc dmt heroin ketamine mescaline methamphetamine mxe methylphenidate alprazolam',
#  'benzos etiz',
#  'benzos etiz',
#  'opioid gabapentin',
#  'mxe dck dmxe mxipr mxpr ephenidine',
#  'mxe dck dmxe mxipr mxpr ephenidine',
#  'odsmt',
#  'odsmt',
#  'etiz',
#  'benzos bromazolam etizolam etiz',
#  'mdma ketamine',
#  'etiz benzo',
#  'etiz benzo',
#  'methamphetamine mdma',
#  'amphetamine',
#  'adderall dopamine',
#  'adderall dopamine',
#  'clonazolam',
#  'ephenidine dmt hexen',
#  'ethylphenidate ephenidine',
#  'ephenidine ethyl dmt meth dpt diphenhydramine',
#  'meth',
#  'meth',
#  'benzos etiz etizolam',
#  'benzos etiz etizolam',
#  'benzos',
#  'mdma',
#  'etizolam diclazepam lorazepam flualprazolam',
#  'etizolam diclazepam lorazepam flualprazolam',
#  'etizolam diclazepam lorazepam flualprazolam',
#  'etizolam diclazepam lorazepam flualprazolam',
#  'etizolam diclazepam lorazepam flualprazolam',
#  'etizolam diclazepam lorazepam flualprazolam',
#  'etizolam diclazepam lorazepam flualprazolam',
#  'ketamine',
#  'opioid',
#  'benzos opioid',
#  'benzos',
#  'benzos pyrazolam benzo',
#  'benzos pyrazolam benzo',
#  'benzos pyrazolam benzo',
#  'odsmt benzos',
#  'alprazolam benzo flualprazolam phenibut',
#  'benzo opioid',
#  'coke ketamine',
#  'coke ketamine',
#  'coke dck ket',
#  'coke dck ket',
#  'adderall klonopin',
#  'etiz',
#  'benzos',
#  'etizolam benzos',
#  'etizolam benzos',
#  'etizolam benzo',
#  'etizolam benzo',
#  'phenethylamine',
#  'phenethylamine',
#  'benzos ketamine dmt dpt heroin meth coke',
#  'norflurazepam gabapentin benzos benzo',
#  'opioid odsmt tramadol',
#  'adderall coke hexen mxe pvp dck etizolam benzos mdma mapb dmt tryptamine acetone amphetamine benzo diclazepam clonazolam',
#  'clonazolam flunitrazolam benzos benzo etizolam clonazepam flubromazolam',
#  'benzo benzos',
#  'benzo benzos',
#  'xtc dmt dck',
#  'klonopin benzos etizolam diclazepam pyrazolam',
#  'alprazolam clonazepam klonopin diazepam lorazepam',
#  'gabapentin kratom heroin',
#  'gabapentin alprazolam kratom pyrazolam amphetamine benzos',
#  'heroin',
#  'dmt',
#  'dmt',
#  'dmt shroom ketamine etizolam benzo',
#  'dmt shroom ketamine etizolam benzo',
#  'dmt shroom ketamine etizolam benzo',
#  'dmt shroom ketamine etizolam benzo',
#  'dmxe',
#  'kratom',
#  'ketamine ket mxe pcm dck',
#  'opioid',
#  'opioid',
#  'coke hexen opioid',
#  'tryptamine',
#  'tryptamine',
#  'dpt',
#  'benzo triazolam alprazolam lorazepam etizolam clonazepam flunitrazepam',
#  'ketamine diazepam ket',
#  'odsmt opioid',
#  'odsmt benzos etazene opioid',
#  'odsmt benzos etazene opioid',
#  'thc',
#  'ketamine gram dck fxe ket',
#  'ketamine diazepam ket',
#  'ketamine diazepam ket',
#  'thc dmxe mxe',
#  'diclazepam benzos',
#  'benzo benzos',
#  'odsmt',
#  'methamphetamine',
#  'methamphetamine',
#  'mda mdma',
#  'benzo pyrazolam norflurazepam',
#  'benzo triazolam midazolam benzos',
#  'benzo triazolam midazolam benzos',
#  'benzo triazolam midazolam benzos',
#  'clonazolam',
#  'dmxe mxe ketamine opioid dck mxipr',
#  'mxe ketamine opioid',
#  'norflurazepam ethanol',
#  'benzos',
#  'benzo',
#  'dopamine amphetamine benzo',
#  'dopamine amphetamine benzo',
#  'dopamine mdma',
#  'heroin',
#  'heroin',
#  'xan',
#  'flualprazolam benzos clonazolam diclazepam diclaz benzo etizolam',
#  'ketamine etizolam benzo alprazolam bromazolam flualprazolam fdck ket adderall',
#  'dmt hexen benzo',
#  'etizolam benzo cannabinoid',
#  'pvp',
#  'benzos mxe',
#  'etizolam',
#  'diazepam',
#  'flunitrazolam etizolam benzos',
#  'cyclazodone ethanol etizolam heroin',
#  'ket',
#  'dmxe dck ketamine',
#  'dmxe dck ketamine',
#  'benzos flubromazolam clonazolam opioid',
#  'clonazolam benzos',
#  'clonazolam mdma dextroamphetamine etizolam benzos alprazolam benzo cathinone coke',
#  'mda etizolam',
#  'clonazolam benzo benzos',
#  'benzos alprazolam diclaz etizolam',
#  'etiz',
#  'clonazolam benzodiazepine clonazepam benzo benzos',
#  'benzo etiz benzos',
#  'clonzolam benzos phenibut',
#  'clonzolam benzos phenibut',
#  'dmxe ketamine dpt dipt dmt mescaline mdma heroin',
#  'cathinone meth',
#  'cathinone gram',
#  'amphetamine meth',
#  'amphetamine meth',
#  'pvp',
#  'mescaline',
#  'mescaline',
#  'mdma dopamine',
#  'flubromazolam benzo benzos',
#  'dopamine phenibut',
#  'dopamine phenibut',
#  'dopamine phenibut',
#  'mxe mdma',
#  'dsmt flubromazolam benzo',
#  'dsmt flubromazolam benzo',
#  'dsmt flubromazolam benzo',
#  'piracetam',
#  'piracetam',
#  'benzo ethanol',
#  'adderall',
#  'mdma',
#  'mda',
#  'mda mdma',
#  'ket dck mdma',
#  'pvp benzos',
#  'meth',
#  'ketamine psilocybin diazepam',
#  'ketamine psilocybin diazepam',
#  'ketamine psilocybin diazepam',
#  'dopamine',
#  'mxe pvp methoxetamine ketamine meth',
#  'mxe ket mdma dmxe',
#  'bromazolam etizolam fluclotizolam flualprazolam clonazolam diclazepam pyrazolam alprazolam diazepam clonazepam flubromazolam benzo',
#  'odsmt',
#  'odsmt',
#  'dck benzos',
#  'dmt',
#  'dmt',
#  'benzos',
#  'etizolam flualprazolam',
#  'etizolam flualprazolam',
#  'benzo benzos',
#  'benzo benzos',
#  'dck mxipr benzo ket',
#  'dck mxipr benzo ket',
#  'dmt',
#  'dmt',
#  'dmt',
#  'mapb mdma etizolam',
#  'mapb mdma etizolam',
#  'pyrazolam benzo',
#  'dsmt clonazolam',
#  'dsmt etizolam',
#  'dsmt etizolam',
#  'cyclazodone',
#  'cyclazodone',
#  'cyclazodone',
#  'benzos clonazolam',
#  'fdck ketamine',
#  'dmt dpt acetone',
#  'dmt',
#  'dmt',
#  'cathinone fxe ketamine',
#  'mdma',
#  'mdma',
#  'amphetamine mdma',
#  'psilocybin dmt',
#  'dpt dmt ketamine',
#  'dmxe mxipr mxpr mxe ephenidine phenethylamine',
#  'ket dmxe dck dopamine ketamine',
#  'adderall',
#  'adderall',
#  'adderall',
#  'tyrosine dopamine methamphetamine',
#  'mdma adderall',
#  'ketamine ket',
#  'meth gram',
#  'meth gram',
#  'dopamine',
#  'adderall',
#  'adderall',
#  'adderall',
#  'ketamine dck mxpr dmxe',
#  'ketamine',
#  'mxe ketamine',
#  'dck',
#  'mxe heroin ketamine phenibut',
#  'mdma benzos',
#  'mdma',
#  'methamphetamine',
#  'methamphetamine',
#  'meth',
#  'dmt',
#  'dmt',
#  'benzo',
#  'bromazolam benzos etizolam flualprazolam fluclotizolam pyrazolam etiz',
#  'gram coke benzos',
#  'coke gram',
#  'coke gram',
#  'coke gram',
#  'meth',
#  'methamphetamine',
#  'amphetamine meth',
#  'dipt',
#  'dipt',
#  'dipt',
#  'dipt',
#  'benzos bromazolam',
#  'benzos',
#  'dck',
#  'dck',
#  'clonazolam',
#  'clonazolam',
#  'benzo',
#  'amphetamine',
#  'gram adderall amphetamine',
#  'gram adderall amphetamine',
#  'dopamine',
#  'dopamine',
#  'mdma',
#  'mdma',
#  'cyclazodone',
#  'alprazolam clonazolam',
#  'clonazolam benzo alprazolam',
#  'cathinone',
#  'cathinone',
#  'mxipr mxpr',
#  'thc mxe ketamine',
#  'mxe mxpr ket',
#  'amphetamine dopamine',
#  'hexen',
#  'psilocybin dmt mdma mda ketamine mescaline dck heroin methamphetamine amphetamine tramadol diazepam lorazepam benzos coke',
#  'methylphenidate lisdexamfetamine amphetamine diphenhydramine doxylamine thc tyrosine psilocybin quetiapine methallylescaline dmt etizolam phenibut phenylpiracetam mdma fasoracetam kratom',
#  'clonazolam glycol',
#  'dopamine adderall phenibut',
#  'dopamine adderall phenibut',
#  'dopamine adderall phenibut',
#  'dopamine adderall phenibut',
#  'mapb',
#  'mapb',
#  'mxe',
#  'dmt mxe pvp mapb',
#  'alprazolam benzo benzos',
#  'benzo benzos mirtazapine dexamphetamine mdma amphetamine cathinone',
#  'methylphenidate',
#  'methylphenidate',
#  'methylphenidate',
#  'methylphenidate',
#  'methylphenidate',
#  'methylphenidate',
#  'diazepam phenazepam benzo methylphenidate etizolam dmxe dmt esketamine dck',
#  'adderall',
#  'adderall',
#  'meth',
#  'amphetamine dopamine',
#  'bromazepam etiz benzo',
#  'heroin meth dopamine',
#  'benzos',
#  'clonazepam',
#  'benzos',
#  'benzos',
#  'dopamine',
#  'dopamine',
#  'dopamine',
#  'dopamine',
#  'mxe benzo flubromazolam',
#  'mxe benzo flubromazolam',
#  'mxe benzo flubromazolam',
#  'cathinone',
#  'benzene cathinone',
#  'diazepam etiz',
#  'diazepam etiz',
#  'dmt',
#  'meth',
#  'dmt mdma mxe',
#  'dmt',
#  'dmt',
#  'diclazepam diazepam benzos benzo',
#  'diclazepam diazepam benzos benzo',
#  'etizolam flubromazolam bromazolam',
#  'mapb trazodone',
#  'mapb trazodone',
#  'amphetamine phenethylamine mescaline',
#  'amphetamine phenethylamine mescaline',
#  'diclaz benzos kratom tramadol',
#  'benzo',
#  'benzo clonazepam',
#  'meth clonazolam benzo',
#  'flunitrazolam benzos bromazolam',
#  'flunitrazolam benzos bromazolam',
#  'benzos etiz benzo',
#  'bromazolam benzo clonazepam',
#  'arylcyclohexylamine',
#  'cathinone',
#  'cathinone',
#  'benzos',
#  'benzos',
#  'pcm mxe arylcyclohexylamine dmxe',
#  'benzos odsmt opioid',
#  'benzos odsmt opioid',
#  'mdma mapb amphetamine',
#  'benzo benzos',
#  'etizolam',
#  'etizolam',
#  'mdma dopamine',
#  'gram',
#  'dsmt odsmt',
#  'amphetamine benzene mdma',
#  'flubromazolam clonazolam',
#  'benzo gram etiz glycol',
#  'diclaz benzo benzos lorazepam',
#  'ethyl dpt dipt tryptamine',
#  'ethyl dpt dipt tryptamine',
#  'dopamine',
#  'dopamine',
#  'amphetamine gram hexen coke',
#  'hexen benzos coke gram',
#  'hexen benzos coke gram',
#  'methylphenidate',
#  'pvp coke',
#  'flualprazolam benzos diclaz gram etiz klonopin alprazolam lorazepam clonazepam benzo',
#  'cathinone dopamine ethyl',
#  'dmxe mxe',
#  'benzos alprazolam etizolam xan etiz',
#  'benzos alprazolam etizolam xan etiz',
#  'benzos alprazolam etizolam xan etiz',
#  'benzos alprazolam etizolam xan etiz',
#  'opioid kratom',
#  'opioid kratom',
#  'opioid kratom',
#  'opioid kratom',
#  'thc dmxe dck mxpr',
#  'thc dmxe dck mxpr',
#  'etizolam meth thc',
#  'mapb',
#  'mapb',
#  'amphetamine',
#  'tryptamine dmt coke',
#  'clonazolam benzo',
#  'clonazolam benzo',
#  'ethyl',
#  'mdma adderall',
#  'gram',
#  'gram',
#  'mdma mda',
#  'gram',
#  'amphetamine dextroamphetamine methamphetamine meth',
#  'amphetamine dextroamphetamine methamphetamine meth',
#  'cannabinoid',
#  'meth',
#  'meth',
#  'meth',
#  'mapb adderall gram',
#  'gram',
#  'clonazepam benzos clonazolam bromazolam etizolam',
#  'bromazepam benzo bromazolam alprazolam flualprazolam benzos',
#  'benzos benzo bromazolam flualprazolam etizolam etiz',
#  'rilmazafone etizolam norflurazepam bromazolam benzo',
#  'dmt',
#  'dmt',
#  'dck',
#  'dck',
#  'clonazolam flubromazolam',
#  'mescaline',
#  'hexen',
#  'benzos',
#  'odsmt',
#  'bromazolam benzo bretazenil',
#  'etizolam benzo ethanol diazepam fluclotizolam bromazolam alprazolam clonazolam',
#  'benzo benzos',
#  'benzo benzos',
#  'coke heroin benzos lorazepam',
#  'benzos phenibut',
#  'benzo etiz',
#  'benzos',
#  'klonopin lorazepam etizolam',
#  'etizolam glycol',
#  'trazodone thc',
#  'benzo',
#  'benzo',
#  'benzo',
#  'clonazolam',
#  'benzo',
#  'benzo',
#  'benzos',
#  'mxe dmt mda',
#  'pvp mxe',
#  'mdma mescaline',
#  'mdma mescaline',
#  'benzos pyrazolam benzo',
#  'norflurazepam benzos odsmt acetone',
#  'norflurazepam benzos odsmt acetone',
#  'phenidate methylphenidate ethylphenidate',
#  'etizolam benzodiazepine lorazepam',
#  'meth',
#  'meth dextroamphetamine coke amphetamine morphin benzo alprazolam gram',
#  'mdma',
#  'mdma',
#  'ethylphenidate methylphenidate',
#  'gram',
#  'gram',
#  'phenibut benzo bromazolam',
#  'ethanol hydrochloride mxe dmxe',
#  'dmxe ethanol',
#  'mapb mda mdma',
#  'mapb mda mdma',
#  'mapb mda mdma',
#  'amphetamine',
#  'alprazolam benzos',
#  'tryptamine mapb dmt mxipr',
#  'odsmt oxy opioid acetone',
#  'clonazolam kratom dsmt heroin',
#  'clonazolam kratom dsmt heroin',
#  'clonazolam kratom dsmt heroin',
#  'tramadol dsmt clonazolam phenibut',
#  'tramadol dsmt clonazolam phenibut',
#  'tryptamine ketamine amphetamine coke',
#  'ket benzo ketamine',
#  'benzos',
#  'benzos benzo klonopin clonazolam etizolam dopamine',
#  'benzos benzo klonopin clonazolam etizolam dopamine',
#  'benzos benzo klonopin clonazolam etizolam dopamine',
#  'etizolam clonazepam',
#  'benzos klonopin',
#  'benzos klonopin',
#  'mdma coke',
#  'mdma coke',
#  'mda',
#  'mda mdma',
#  'mda mdma',
#  'mda mdma',
#  'benzos bromazolam fluclotizolam flualprazolam clonazolam benzo',
#  'benzos bromazolam fluclotizolam flualprazolam clonazolam benzo',
#  'amphetamine',
#  'amphetamine',
#  'amphetamine',
#  'glycol',
#  'etiz',
#  'etiz',
#  'benzos etizolam',
#  'benzos etizolam',
#  'benzos etizolam',
#  'benzos etizolam',
#  'benzos etizolam',
#  'kratom thc mdma',
#  'acetone',
#  'acetone dmt gram',
#  'coke meth mdma benzo',
#  'diazepam benzo',
#  'benzos',
#  'benzos',
#  'benzos',
#  'benzos',
#  'benzos etizolam benzo',
#  'gabapentin flualprazolam benzos',
#  'etizolam',
#  'dopamin methylphenidate tyrosine',
#  'adderall',
#  'adderall',
#  'mdma',
#  'mdma',
#  'mdma',
#  'gram',
#  'fluclotizolam etizolam benzodiazepine diazepine etiz',
#  'tryptamine dmt mdma',
#  'mdma',
#  'cathinone benzos bromazolam etiz benzo',
#  'benzos',
#  'ethanol benzos phenibut',
#  'meth heroin kratom',
#  'methylphenidate coke',
#  'etizolam flualprazolam benzos pyrazolam alprazolam',
#  'etizolam flualprazolam benzos pyrazolam alprazolam',
#  'etizolam flualprazolam benzos pyrazolam alprazolam',
#  'etizolam flualprazolam benzos pyrazolam alprazolam',
#  'phenethylamine',
#  'phenazepam flubromazolam benzos',
#  'bromazolam pyrazolam',
#  'bromazolam pyrazolam',
#  'opioid dmxe',
#  'opioid dmxe',
#  'opioid dmxe',
#  'kratom',
#  'oxy',
#  'benzo',
#  'benzos',
#  'benzos pyrazolam diclazepam benzo phenibut',
#  'clonazepam benzodiazepine',
#  'meth',
#  'meth',
#  'flunitrazolam benzo',
#  'benzos etizolam bromazolam nitrazolam benzo',
#  'benzos etizolam bromazolam nitrazolam benzo',
#  'benzos etizolam bromazolam nitrazolam benzo',
#  'benzos etizolam bromazolam nitrazolam benzo',
#  'ketamine',
#  'ketamine dck ket mdma dmt',
#  'dck ketamine dmxe mapb mdma dmt benzos',
#  'flunitrazolam clonazolam benzos alprazolam clonazepam',
#  'clonazolam coke',
#  'clonazolam coke',
#  'amphetamine',
#  'benzos',
#  'benzo',
#  'heroin benzos',
#  'heroin benzos',
#  'heroin benzos',
#  'gram',
#  'dmt',
#  'odsmt',
#  'mxe ket ketamine',
#  'benzos',
#  'dmt ket',
#  'dmt ket',
#  'dmt ket',
#  'dmt ket',
#  'dopamine amphetamine bromazolam mdma',
#  'dopamine amphetamine bromazolam mdma',
#  'dopamine amphetamine bromazolam mdma',
#  'mdma hexen amphetamine',
#  'benzo benzos',
#  'mdma',
#  'acetone clonazolam',
#  'hexen',
#  'benzo diclaz gabapentin',
#  'benzos diazepam benzo',
#  'amphetamine adderall benzo kpin benzos',
#  'benzo isopropylphenidate benzos etizolam pyrazolam diclazepam fluclotizolam clonazepam bromazolam',
#  'benzo isopropylphenidate benzos etizolam pyrazolam diclazepam fluclotizolam clonazepam bromazolam',
#  'benzo isopropylphenidate benzos etizolam pyrazolam diclazepam fluclotizolam clonazepam bromazolam',
#  'benzo isopropylphenidate benzos etizolam pyrazolam diclazepam fluclotizolam clonazepam bromazolam',
#  'hexen',
#  'hexen',
#  'amphetamine',
#  'amphetamine',
#  'amphetamine',
#  'bromazolam',
#  'dopamine pvp meth coke',
#  'acetone',
#  'acetone coke',
#  'acetone coke',
#  'acetone coke',
#  'acetone coke',
#  'acetone coke',
#  'acetone coke',
#  'mapb mdma mda',
#  'mapb mdma',
#  'mapb mdma',
#  'mapb mdma',
#  'mapb mdma dopamine mescaline',
#  'mapb adderall tryptamine mdma',
#  'mapb mxipr adderall dmxe methallylescaline mdma',
#  'benzos etizolam pyrazolam benzo diclazepam fluclotizolam clonazepam bromazolam',
#  'benzodiazepine',
#  'etizolam ethanol',
#  'meth amphetamine pvp',
#  'phenibut dopamine mapb',
#  'phenibut dopamine mapb',
#  'ket',
#  'ketamine ket',
#  'kratom dsmt tramadol',
#  'allylescaline mescaline',
#  'allylescaline mescaline',
#  'dmt meth',
#  'mda',
#  'mda',
#  'dipt dpt dmt',
#  'dmt',
#  'mdma',
#  'adderall',
#  'isopropylphenidate',
#  'isopropylphenidate',
#  'ketamin ketamine',
#  'ketamin ketamine',
#  'tramadol heroin',
#  'tramadol dmt ketamine heroin',
#  'dsmt',
#  'odsmt dsmt',
#  'dmt',
#  'ethanol',
#  'dmt glycol',
#  'benzo etizolam etiz',
#  'clonazepam clonazolam etizolam etiz benzo',
#  'benzo',
#  'clonazolam',
#  'clonazolam',
#  'clonazepam benzos benzo',
#  'alprazolam clonazolam benzos bromazolam klonopin benzo',
#  'klonopin benzos benzo flubromazolam',
#  'klonopin clonazolam',
#  'klonopin clonazolam',
#  'klonopin clonazolam',
#  'klonopin clonazolam',
#  'benzos',
#  'thc',
#  'phenibut benzos clonazepam',
#  'phenibut benzos clonazepam',
#  'psilocybin mescaline alprazolam',
#  'heroin',
#  'heroin',
#  'phenibut',
#  'mdma',
#  'tryptamine mdma',
#  'diazepam',
#  'gram diclaz klonopin',
#  'gram diclaz klonopin',
#  'phenibut thc mdma',
#  'phenibut thc mdma',
#  'phenibut thc mdma',
#  'meth',
#  'benzo phenibut',
#  'fdck',
#  'diclazepam benzos clonazepam pyrazolam',
#  'diclazepam benzos clonazepam pyrazolam',
#  'diclazepam benzos clonazepam pyrazolam',
#  'mdma benzo',
#  'heroin etizolam',
#  'heroin etizolam',
#  ...]

# %%
data['drugs_in_text'] = drug_terms

# %%
to_database = data.drop(['split_text','counter','general_words_removed','drugsremoved'], axis=1)

# %%
to_database
# Out:
#            id                                               text  \
# 20     q6hjm6  i don t have much experience with pg solutions...
# 28     q6igkm    mph    flouromethylphenidate   while not hav...
# 34     q6k9vd  it seems like an accurate name for what it is ...
# 35     q6k9vd  i think as it stands now people take the defin...
# 39     q6k9vd  i ve started to have some pretty hot takes on ...
# ...       ...                                                ...
# 57864  lko5k0  imo the dnm is perfect  escrow  pgp and ebay s...
# 57869  lko5k0  not that i “prefer”  my goal is to try everyth...
# 57873  lko5k0  hey everyone  so i’m wondering why you all pre...
# 57875  lko5vp  hi  so i ve never turned anything into freebas...
# 57885  lkqec1  hi  i got a delivery of     etizolam and     e...
#
#                  timestamp      effect  \
# 20     2021-10-12 04:28:41  Psycadelic
# 28     2021-10-12 05:38:03  Psycadelic
# 34     2021-10-12 07:42:56  Psycadelic
# 35     2021-10-12 07:42:56    Euphoric
# 39     2021-10-12 07:42:56  Psycadelic
# ...                    ...         ...
# 57864  2021-02-15 16:52:07   Dangerous
# 57869  2021-02-15 16:52:07    Negative
# 57873  2021-02-15 16:52:07    Euphoric
# 57875  2021-02-15 16:52:33  Psycadelic
# 57885  2021-02-15 18:39:46  Psycadelic
#
#                                            drugs_in_text
# 20                               etiz ethanol diclazepam
# 28     fluoromethylphenidate methylphenidate dopamine...
# 34     fluoromethylphenidate methylphenidate dopamine...
# 35     fluoromethylphenidate methylphenidate dopamine...
# 39     fluoromethylphenidate methylphenidate dopamine...
# ...                                                  ...
# 57864  ketamine diclazepam diazepam benzos amphetamin...
# 57869                                            dpt dmt
# 57873                                            dpt dmt
# 57875                                                dmt
# 57885                                   etizolam etazene
#
# [10075 rows x 5 columns]

# %%
to_database_dict = to_database.to_dict()

# %%
to_database_dict
# Out:
# {'id': {'20': 'q6hjm6',
#   '28': 'q6igkm',
#   '34': 'q6k9vd',
#   '35': 'q6k9vd',
#   '39': 'q6k9vd',
#   '43': 'q6mf31',
#   '45': 'q6mf31',
#   '54': 'q6mga2',
#   '55': 'q6mga2',
#   '83': 'q6mga2',
#   '92': 'q6nrx9',
#   '95': 'q6nrx9',
#   '99': 'q6of09',
#   '100': 'q6of09',
#   '108': 'q6pfeo',
#   '118': 'q6rrys',
#   '149': 'q6uqwe',
#   '154': 'q6uqwe',
#   '218': 'q6zj22',
#   '237': 'q6zj22',
#   '243': 'q72yeb',
#   '244': 'q72yeb',
#   '247': 'q72yeb',
#   '249': 'q74m6a',
#   '272': 'q78pvd',
#   '331': 'q7ezax',
#   '353': 'q7fsnu',
#   '376': 'q7i45d',
#   '381': 'q7jdy9',
#   '383': 'q5qh7z',
#   '392': 'q5qm4q',
#   '405': 'q5rsnm',
#   '412': 'q5rsnm',
#   '422': 'q5wxzr',
#   '429': 'q5yshj',
#   '459': 'q635f9',
#   '469': 'q63y4h',
#   '475': 'q668zu',
#   '481': 'q66xf7',
#   '482': 'q66xf7',
#   '495': 'q66xf7',
#   '497': 'q66xf7',
#   '500': 'q68wod',
#   '518': 'q5327a',
#   '523': 'q537uj',
#   '524': 'q537uj',
#   '529': 'q537uj',
#   '538': 'q53bzn',
#   '549': 'q58gz7',
#   '558': 'q5azqk',
#   '572': 'q5dhv6',
#   '596': 'q5fxh8',
#   '597': 'q5fxh8',
#   '599': 'q5fxh8',
#   '613': 'q5g29v',
#   '615': 'q5g29v',
#   '620': 'q5hphu',
#   '622': 'q5hvfv',
#   '625': 'q5hvfv',
#   '631': 'q5iglo',
#   '638': 'q5iglo',
#   '653': 'q5jsg1',
#   '659': 'q5kqll',
#   '663': 'q5la9e',
#   '674': 'q5mmpt',
#   '679': 'q5muie',
#   '692': 'q4eohs',
#   '700': 'q4fen3',
#   '720': 'q4g8co',
#   '726': 'q4h4a0',
#   '730': 'q4iowu',
#   '737': 'q4iowu',
#   '772': 'q4nt7g',
#   '796': 'q4peq9',
#   '799': 'q4peq9',
#   '800': 'q4pgtz',
#   '832': 'q4rm15',
#   '842': 'q4rt6c',
#   '845': 'q4rt6c',
#   '856': 'q4rt6c',
#   '858': 'q4rt6c',
#   '860': 'q4svb8',
#   '862': 'q4svb8',
#   '890': 'q4vv15',
#   '897': 'q4vz94',
#   '900': 'q4vz94',
#   '913': 'q50811',
#   '947': 'q3qmd0',
#   '960': 'q3rpmn',
#   '961': 'q3rpmn',
#   '964': 'q3rpmn',
#   '970': 'q3si06',
#   '975': 'q3si06',
#   '977': 'q3si06',
#   '980': 'q3si06',
#   '1024': 'q34xd4',
#   '1029': 'q34xd4',
#   '1030': 'q34xd4',
#   '1042': 'q37h0a',
#   '1052': 'q3chja',
#   '1076': 'q3deqv',
#   '1083': 'q3f5xi',
#   '1087': 'q3f5xi',
#   '1091': 'q3g03d',
#   '1095': 'q3g6ce',
#   '1108': 'q3hzsg',
#   '1112': 'q3ivy9',
#   '1114': 'q3ivy9',
#   '1123': 'q3ivy9',
#   '1124': 'q3ivy9',
#   '1125': 'q3ivy9',
#   '1139': 'q2f1ku',
#   '1145': 'q2f1ku',
#   '1150': 'q2firs',
#   '1162': 'q2hvmv',
#   '1166': 'q2hvmv',
#   '1185': 'q2jto4',
#   '1187': 'q2jto4',
#   '1194': 'q2jto4',
#   '1197': 'q2jto4',
#   '1200': 'q2l1cm',
#   '1223': 'q2ls86',
#   '1229': 'q2ntmo',
#   '1243': 'q2qfc6',
#   '1249': 'q2qfc6',
#   '1250': 'q2qfc6',
#   '1255': 'q2qil8',
#   '1257': 'q2qil8',
#   '1261': 'q2qil8',
#   '1280': 'q2smqi',
#   '1286': 'q2tgx4',
#   '1319': 'q2xqu9',
#   '1356': 'q2zede',
#   '1371': 'q30ilk',
#   '1372': 'q30l0n',
#   '1376': 'q1nej9',
#   '1379': 'q1nej9',
#   '1380': 'q1o024',
#   '1383': 'q1o024',
#   '1384': 'q1o024',
#   '1386': 'q1o024',
#   '1389': 'q1o024',
#   '1390': 'q1o024',
#   '1396': 'q1o024',
#   '1401': 'q1o024',
#   '1408': 'q1o024',
#   '1409': 'q1p0zg',
#   '1412': 'q1p0zg',
#   '1427': 'q1scpq',
#   '1431': 'q1scpq',
#   '1435': 'q1u9l5',
#   '1439': 'q1u9l5',
#   '1457': 'q1ygbu',
#   '1461': 'q1ygbu',
#   '1464': 'q1ygbu',
#   '1470': 'q1ygbu',
#   '1480': 'q20xie',
#   '1492': 'q21xdl',
#   '1513': 'q24v98',
#   '1518': 'q25ltb',
#   '1539': 'q27amv',
#   '1553': 'q27amv',
#   '1585': 'q2av1c',
#   '1586': 'q2biqg',
#   '1591': 'q2biqg',
#   '1593': 'q2biqg',
#   '1594': 'q2biqg',
#   '1595': 'q2biqg',
#   '1597': 'q2bjiu',
#   '1599': 'q2bjiu',
#   '1601': 'q2bjiu',
#   '1608': 'q0zcsb',
#   '1618': 'q0zcsb',
#   '1633': 'q0zcsb',
#   '1661': 'q0zcsb',
#   '1675': 'q10fbb',
#   '1679': 'q10jz3',
#   '1681': 'q10rcd',
#   '1696': 'q143yx',
#   '1710': 'q15luu',
#   '1719': 'q15luu',
#   '1728': 'q18q8a',
#   '1730': 'q18q8a',
#   '1736': 'q1bk19',
#   '1737': 'q1cjhg',
#   '1738': 'q1cjhg',
#   '1742': 'q1cjhg',
#   '1747': 'q1djo8',
#   '1758': 'q1djo8',
#   '1778': 'q1e8n2',
#   '1815': 'q1iqk9',
#   '1825': 'q1miqv',
#   '1849': 'q0al4q',
#   '1853': 'q0al4q',
#   '1857': 'q0al4q',
#   '1861': 'q0al4q',
#   '1866': 'q0al4q',
#   '1867': 'q0al4q',
#   '1868': 'q0al4q',
#   '1873': 'q0al4q',
#   '1881': 'q0al4q',
#   '1884': 'q0alr9',
#   '1886': 'q0alr9',
#   '1894': 'q0bbc8',
#   '1898': 'q0bjps',
#   '1903': 'q0bvpl',
#   '1919': 'q0dwdb',
#   '1922': 'q0dwdb',
#   '1934': 'q0dwdb',
#   '1938': 'q0euxa',
#   '1945': 'q0gar0',
#   '1949': 'q0gar0',
#   '1955': 'q0h3or',
#   '1961': 'q0h3or',
#   '1996': 'q0k384',
#   '2005': 'q0pupf',
#   '2009': 'q0rsfz',
#   '2014': 'q0sdmt',
#   '2018': 'q0sdmt',
#   '2031': 'q0uf49',
#   '2034': 'q0uf49',
#   '2044': 'q0vfk5',
#   '2061': 'q0wizy',
#   '2073': 'q0wzsy',
#   '2074': 'q0wzsy',
#   '2076': 'q0wzsy',
#   '2086': 'pzpnzl',
#   '2094': 'pzq5cg',
#   '2100': 'pzq5cg',
#   '2101': 'pzqvna',
#   '2103': 'pzqvna',
#   '2104': 'pzqvna',
#   '2108': 'pzs9za',
#   '2109': 'pzs9za',
#   '2112': 'pzs9za',
#   '2121': 'pzu7nk',
#   '2127': 'pzu7nk',
#   '2133': 'pzugks',
#   '2135': 'pzugks',
#   '2136': 'pzugks',
#   '2143': 'pzx2ai',
#   '2155': 'pzy5v0',
#   '2159': 'pzy5v0',
#   '2160': 'pzy5v0',
#   '2163': 'pzy5v0',
#   '2165': 'pzy5v0',
#   '2186': 'pzy5v0',
#   '2187': 'pzz5nu',
#   '2206': 'q00rac',
#   '2207': 'q014rd',
#   '2208': 'q014rd',
#   '2217': 'q04cct',
#   '2220': 'q04cct',
#   '2224': 'q05w0u',
#   '2226': 'q05w0u',
#   '2233': 'q05w0u',
#   '2235': 'q05w0u',
#   '2245': 'q071v5',
#   '2247': 'q07lta',
#   '2250': 'q07lta',
#   '2264': 'q08ayi',
#   '2277': 'pz4tgm',
#   '2299': 'pz5xj7',
#   '2328': 'pz7a8v',
#   '2340': 'pz7w4c',
#   '2341': 'pz7w4c',
#   '2345': 'pz7w4c',
#   '2346': 'pz7w4c',
#   '2357': 'pz8llj',
#   '2379': 'pzb976',
#   '2383': 'pzb976',
#   '2386': 'pzblij',
#   '2392': 'pzcv7n',
#   '2408': 'pzcvy8',
#   '2411': 'pzcx4d',
#   '2412': 'pzcx4d',
#   '2414': 'pzd0h2',
#   '2429': 'pzeejw',
#   '2444': 'pzfjau',
#   '2456': 'pzg26k',
#   '2476': 'pzg2wq',
#   '2490': 'pzgu3j',
#   '2491': 'pzgu3j',
#   '2512': 'pzgycl',
#   '2577': 'pyd2ql',
#   '2598': 'pyfiig',
#   '2611': 'pyh50f',
#   '2626': 'pymnpd',
#   '2638': 'pynz8v',
#   '2659': 'pyp6oh',
#   '2662': 'pypo35',
#   '2683': 'pyr6fd',
#   '2689': 'pysfwa',
#   '2691': 'pyt15y',
#   '2699': 'pytpd1',
#   '2729': 'pyu3us',
#   '2732': 'pyu3us',
#   '2741': 'pyudg8',
#   '2750': 'pyuss8',
#   '2765': 'pywqfw',
#   '2770': 'pyyjgb',
#   '2771': 'pyyjgb',
#   '2772': 'pyyjgb',
#   '2785': 'pyzhx2',
#   '2811': 'pz00f0',
#   '2813': 'pxotdi',
#   '2823': 'pxqh5x',
#   '2827': 'pxqrp9',
#   '2873': 'pxrvws',
#   '2883': 'pxsbh1',
#   '2884': 'pxsbh1',
#   '2886': 'pxsbh1',
#   '2889': 'pxsbh1',
#   '2894': 'pxt0vy',
#   '2897': 'pxu4kp',
#   '2900': 'pxu4kp',
#   '2902': 'pxu4kp',
#   '2903': 'pxu4kp',
#   '2907': 'pxu4kp',
#   '2913': 'pxu4kp',
#   '2914': 'pxu4kp',
#   '2915': 'pxu4kp',
#   '2916': 'pxu4kp',
#   '2918': 'pxu4kp',
#   '2921': 'pxu4kp',
#   '2925': 'pxu4kp',
#   '2926': 'pxu4kp',
#   '2935': 'pxwaat',
#   '2937': 'pxwaat',
#   '2942': 'pxwaat',
#   '2948': 'pxwu3k',
#   '2958': 'py05rt',
#   '2959': 'py05rt',
#   '2990': 'py2ib7',
#   '2992': 'py3n4m',
#   '2995': 'py3n4m',
#   '3006': 'py47w3',
#   '3039': 'py4m1a',
#   '3043': 'py4m1a',
#   '3047': 'py4m1a',
#   '3052': 'py4xal',
#   '3063': 'py51co',
#   '3069': 'py5pln',
#   '3081': 'py5pln',
#   '3089': 'py6e98',
#   '3096': 'py6hq5',
#   '3125': 'py8p2o',
#   '3127': 'py8p2o',
#   '3134': 'py9wrt',
#   '3136': 'py9wrt',
#   '3137': 'pyaeox',
#   '3148': 'pybu2h',
#   '3150': 'pwy5q0',
#   '3151': 'pwy5q0',
#   '3158': 'px0z28',
#   '3160': 'px0z28',
#   '3163': 'px0z28',
#   '3218': 'pxbw7e',
#   '3230': 'pxc55w',
#   '3231': 'pxc55w',
#   '3233': 'pxc55w',
#   '3238': 'pxcu5t',
#   '3239': 'pxcu5t',
#   '3267': 'pxdtac',
#   '3313': 'pxf4fm',
#   '3317': 'pxgd0f',
#   '3337': 'pxgwau',
#   '3352': 'pxgwgq',
#   '3357': 'pxhocu',
#   '3359': 'pxjfnv',
#   '3364': 'pxjfnv',
#   '3367': 'pxjqdm',
#   '3376': 'pxks7e',
#   '3381': 'pxlvfx',
#   '3387': 'pw9o44',
#   '3419': 'pw9o44',
#   '3421': 'pwa381',
#   '3423': 'pwa381',
#   '3427': 'pwa381',
#   '3434': 'pwa7qc',
#   '3445': 'pwc4ok',
#   '3453': 'pweri7',
#   '3457': 'pweri7',
#   '3460': 'pweri7',
#   '3471': 'pwfe89',
#   '3475': 'pwfe89',
#   '3485': 'pwfe89',
#   '3521': 'pwlmj8',
#   '3532': 'pwoyb2',
#   '3538': 'pwreir',
#   '3542': 'pwreir',
#   '3547': 'pwreir',
#   '3563': 'pwreir',
#   '3568': 'pwreir',
#   '3597': 'pws4e0',
#   '3604': 'pwshw6',
#   '3605': 'pwtmsj',
#   '3616': 'pwutkj',
#   '3618': 'pwv1dt',
#   '3622': 'pwvada',
#   '3639': 'pwvada',
#   '3647': 'pwx334',
#   '3656': 'pwx334',
#   '3681': 'pvoh49',
#   '3683': 'pvoh49',
#   '3685': 'pvoj9f',
#   '3706': 'pvoj9f',
#   '3722': 'pvq6qk',
#   '3723': 'pvq6qk',
#   '3726': 'pvqwg9',
#   '3727': 'pvre0u',
#   '3728': 'pvre0u',
#   '3734': 'pvre0u',
#   '3735': 'pvtbk6',
#   '3736': 'pvtbk6',
#   '3740': 'pvtbk6',
#   '3757': 'pvvim2',
#   '3762': 'pvw5p4',
#   '3763': 'pvwb37',
#   '3765': 'pvwb37',
#   '3768': 'pvwb37',
#   '3775': 'pvwqx0',
#   '3776': 'pvwv1k',
#   '3779': 'pvwv1k',
#   '3789': 'pvygfr',
#   '3798': 'pw0jfi',
#   '3808': 'pw12pj',
#   '3812': 'pw1fkv',
#   '3814': 'pw1fkv',
#   '3853': 'pw2y4u',
#   '3859': 'pw32rx',
#   '3866': 'pw4b6g',
#   '3868': 'pw4b6g',
#   '3882': 'puzmqq',
#   '3885': 'puzmqq',
#   '3886': 'puzzwc',
#   '3888': 'puzzwc',
#   '3905': 'pv2f4j',
#   '3907': 'pv2rsb',
#   '3923': 'pv3mom',
#   '3924': 'pv3mom',
#   '3925': 'pv480a',
#   '3933': 'pv480a',
#   '3948': 'pv4kco',
#   '3964': 'pv5dr0',
#   '3983': 'pv8p9k',
#   '3988': 'pv9af9',
#   '3989': 'pv9af9',
#   '4042': 'pvee6u',
#   '4052': 'pvf2o9',
#   '4053': 'pvf6vv',
#   '4078': 'pvjgm6',
#   '4080': 'pvjgm6',
#   '4103': 'pvl6p7',
#   '4127': 'pufx6c',
#   '4156': 'puif92',
#   '4164': 'puinhr',
#   '4165': 'puinhr',
#   '4176': 'pulskj',
#   '4195': 'pulskj',
#   '4199': 'pulskj',
#   '4230': 'pulug0',
#   '4233': 'pum25v',
#   '4239': 'pumhr3',
#   '4245': 'pumk6u',
#   '4250': 'punj1r',
#   '4252': 'puo680',
#   '4271': 'puqokd',
#   '4286': 'pur93p',
#   '4298': 'purbwa',
#   '4303': 'puspvk',
#   '4332': 'puvjg4',
#   '4349': 'puw07k',
#   '4365': 'puw07k',
#   '4390': 'puxfaf',
#   '4392': 'puxfaf',
#   '4396': 'puxfaf',
#   '4398': 'puxfaf',
#   '4411': 'puxfaf',
#   '4418': 'ptn4fn',
#   '4422': 'ptnr9t',
#   '4424': 'ptnr9t',
#   '4429': 'ptobqw',
#   '4432': 'ptobqw',
#   '4456': 'pts4za',
#   '4457': 'pts4za',
#   '4495': 'ptshjf',
#   '4499': 'ptsol7',
#   '4511': 'ptspq5',
#   '4529': 'ptwjhy',
#   '4559': 'ptyn4v',
#   '4562': 'ptyou8',
#   '4568': 'ptys3t',
#   '4569': 'ptyvuj',
#   '4590': 'ptyvuj',
#   '4611': 'ptzvfr',
#   '4614': 'pu09xw',
#   '4624': 'pu2l74',
#   '4642': 'pu4a6s',
#   '4643': 'pu4a6s',
#   '4646': 'pu4jg9',
#   '4647': 'pu4jg9',
#   '4650': 'pu7i51',
#   '4651': 'pu7i51',
#   '4652': 'pu7i51',
#   '4654': 'pu7jli',
#   '4658': 'pu7jli',
#   '4661': 'pu7jli',
#   '4662': 'pu7jli',
#   '4666': 'pu7jli',
#   '4668': 'pu7jli',
#   '4705': 'pu82dy',
#   '4706': 'pu84gx',
#   '4708': 'pu84gx',
#   '4721': 'pu8hz2',
#   '4745': 'pt0fma',
#   '4752': 'pt2fa3',
#   '4770': 'pt34l6',
#   '4795': 'pt6h96',
#   '4796': 'pt6vgl',
#   '4834': 'ptcjm5',
#   '4855': 'ptfcr2',
#   '4861': 'ptfqwv',
#   '4876': 'pth8y5',
#   '4899': 'ptmtqz',
#   '4912': 'pscrn1',
#   '4930': 'psgin7',
#   '4933': 'psgin7',
#   '4934': 'psgin7',
#   '4996': 'psmiyy',
#   '5019': 'psobhr',
#   '5031': 'psow6i',
#   '5033': 'psp76m',
#   '5040': 'pspe9a',
#   '5044': 'pspe9a',
#   '5048': 'pspxel',
#   '5080': 'psrdu3',
#   '5114': 'psthdh',
#   '5118': 'psthdh',
#   '5138': 'psucnm',
#   '5152': 'psuuef',
#   '5158': 'pswkvf',
#   '5164': 'psyoll',
#   '5177': 'prpeqi',
#   '5191': 'prtjmk',
#   '5206': 'pruvda',
#   '5225': 'prxhuq',
#   '5227': 'prxhuq',
#   '5237': 'prxpu0',
#   '5255': 'pry3rs',
#   '5261': 'pry3rs',
#   '5280': 'przfqd',
#   '5291': 'ps3ih2',
#   '5297': 'ps3zlh',
#   '5298': 'ps3zlh',
#   '5299': 'ps3zlh',
#   '5301': 'ps3zlh',
#   '5312': 'ps4wfy',
#   '5319': 'ps7eou',
#   '5349': 'ps9jre',
#   '5351': 'ps9jre',
#   '5378': 'pr305w',
#   '5379': 'pr305w',
#   '5397': 'pr53qp',
#   '5399': 'pr5nxd',
#   '5401': 'pr5nxd',
#   '5402': 'pr5nxd',
#   '5405': 'pr5nxd',
#   '5408': 'pr5nxd',
#   '5410': 'pr77xo',
#   '5418': 'pr77xo',
#   '5420': 'pr8ie6',
#   '5423': 'pr8ie6',
#   '5427': 'pr8ie6',
#   '5428': 'pr8ie6',
#   '5432': 'pr8ie6',
#   '5441': 'pr8txa',
#   '5443': 'pr8txa',
#   '5452': 'pr9f9x',
#   '5455': 'pr9f9x',
#   '5464': 'pr9h1i',
#   '5465': 'pr9h1i',
#   '5470': 'pr9ov7',
#   '5495': 'pr9ov7',
#   '5504': 'pr9ov7',
#   '5505': 'prb2ji',
#   '5512': 'prc3az',
#   '5513': 'prc3az',
#   '5533': 'pree2h',
#   '5548': 'prgg1c',
#   '5550': 'prgg1c',
#   '5555': 'prhuwu',
#   '5558': 'prk01o',
#   '5562': 'prlgz2',
#   '5583': 'pqiict',
#   '5587': 'pqjfnp',
#   '5612': 'pqn4n0',
#   '5624': 'pqn4n0',
#   '5625': 'pqn4n0',
#   '5637': 'pqn4n0',
#   '5644': 'pqn4n0',
#   '5645': 'pqn4n0',
#   '5650': 'pqn4n0',
#   '5657': 'pqn89h',
#   '5658': 'pqna7f',
#   '5676': 'pqna7f',
#   '5687': 'pqnog0',
#   '5694': 'pqo2so',
#   '5710': 'pqpzky',
#   '5713': 'pqqeyw',
#   '5728': 'pqqeyw',
#   '5745': 'pqt77u',
#   '5754': 'pqudmk',
#   '5782': 'pqvajw',
#   '5794': 'pqvajw',
#   '5837': 'pqwdnt',
#   '5844': 'ppswlj',
#   '5852': 'ppu12x',
#   '5853': 'ppu2zh',
#   '5855': 'ppu2zh',
#   '5863': 'ppwizh',
#   '5896': 'ppyw2g',
#   '5915': 'ppywxs',
#   '5917': 'ppywxs',
#   '5921': 'ppzi5v',
#   '5933': 'ppzqzp',
#   '5947': 'pq1u9u',
#   '5952': 'pq1u9u',
#   '5953': 'pq1u9u',
#   '5977': 'pq5yh2',
#   '5981': 'pq6gt0',
#   '5991': 'pq88jx',
#   '5997': 'pq88jx',
#   '6003': 'pq88jx',
#   '6004': 'pq88jx',
#   '6005': 'pq88jx',
#   '6011': 'pq88jx',
#   '6017': 'pq88jx',
#   '6022': 'pq88jx',
#   '6026': 'pq88jx',
#   '6029': 'pq88jx',
#   '6031': 'pq88jx',
#   '6044': 'pq88jx',
#   '6046': 'pq88jx',
#   '6058': 'pq88jx',
#   '6059': 'pq88jx',
#   '6060': 'pq88jx',
#   '6061': 'pq88jx',
#   '6070': 'pq88jx',
#   '6073': 'pq8k8c',
#   '6074': 'pq8k8c',
#   '6081': 'pq8k8c',
#   '6088': 'pqab3d',
#   '6109': 'pqbs1s',
#   '6128': 'pqbs1s',
#   '6138': 'pqbs1s',
#   '6145': 'pqbs1s',
#   '6150': 'pqbs1s',
#   '6158': 'pqbs1s',
#   '6162': 'pqd74e',
#   '6170': 'pqdciv',
#   '6171': 'pqdciv',
#   '6177': 'pqepdy',
#   '6180': 'pp5zu9',
#   '6181': 'pp5zu9',
#   '6193': 'pp6d81',
#   '6194': 'pp6d81',
#   '6198': 'pp6d81',
#   '6200': 'pp6ufk',
#   '6217': 'pp6ufk',
#   '6223': 'pp7jxj',
#   '6224': 'pp7jxj',
#   '6227': 'pp7x52',
#   '6230': 'pp7x52',
#   '6237': 'pp87rw',
#   '6243': 'pp8sea',
#   '6250': 'pp8sea',
#   '6288': 'ppdwzq',
#   '6294': 'ppdwzq',
#   '6304': 'ppea3z',
#   '6309': 'ppea3z',
#   '6310': 'ppea3z',
#   '6328': 'ppfkop',
#   '6338': 'ppg02s',
#   '6339': 'ppg02s',
#   '6343': 'ppg8lv',
#   '6344': 'pph5em',
#   '6362': 'pph5em',
#   '6368': 'pphde4',
#   '6369': 'pphp0r',
#   '6383': 'pphtxl',
#   '6389': 'pphtxl',
#   '6390': 'ppi0vg',
#   '6398': 'ppijq5',
#   '6427': 'ppjri5',
#   '6432': 'ppkmga',
#   '6436': 'ppkn0f',
#   '6452': 'ppn1ju',
#   '6454': 'ppn1ju',
#   '6474': 'pps1xp',
#   '6477': 'pps1xp',
#   '6494': 'poj16v',
#   '6501': 'poj4wl',
#   '6515': 'pokarp',
#   '6522': 'pokecr',
#   '6530': 'pola8c',
#   '6535': 'polomx',
#   '6538': 'polomx',
#   '6540': 'polomx',
#   '6543': 'polomx',
#   '6552': 'polomx',
#   '6560': 'polomx',
#   '6563': 'polomx',
#   '6567': 'polqho',
#   '6572': 'pom4oo',
#   '6575': 'pomm52',
#   '6595': 'pooq6g',
#   '6603': 'porhqn',
#   '6605': 'porhqn',
#   '6612': 'posis1',
#   '6618': 'poszwm',
#   '6623': 'potlps',
#   '6624': 'potlps',
#   '6626': 'potlps',
#   '6627': 'potlps',
#   '6634': 'potsby',
#   '6637': 'potsby',
#   '6642': 'pouug0',
#   '6658': 'poxw9b',
#   '6677': 'poy726',
#   '6682': 'poy726',
#   '6686': 'poy726',
#   '6698': 'poy726',
#   '6699': 'poy726',
#   '6724': 'pp2mi7',
#   '6731': 'pp2ubm',
#   '6791': 'pnzzlc',
#   '6792': 'pnzzlc',
#   '6797': 'pnzzlc',
#   '6805': 'po10mi',
#   '6828': 'po20za',
#   '6833': 'po2ahq',
#   '6851': 'po3qzb',
#   '6861': 'po4i74',
#   '6875': 'po5yky',
#   '6882': 'po7u2z',
#   '6951': 'pocwke',
#   '6988': 'pod4nt',
#   '7003': 'poe596',
#   '7005': 'pofihn',
#   '7008': 'pog30i',
#   '7012': 'pogdjt',
#   '7013': 'poge48',
#   '7023': 'pn8k8g',
#   '7027': 'pn8k8g',
#   '7035': 'pn8k8g',
#   '7037': 'pn8k8g',
#   '7038': 'pn8k8g',
#   '7046': 'pna1qq',
#   '7049': 'pna2ax',
#   '7057': 'pnb9wk',
#   '7069': 'pncb5z',
#   '7078': 'pncb5z',
#   '7087': 'pnd1rt',
#   '7091': 'pndh53',
#   '7098': 'pndh53',
#   '7116': 'pngec9',
#   '7143': 'pnhj19',
#   '7170': 'pnhj19',
#   '7180': 'pnhj19',
#   '7192': 'pni4u9',
#   '7211': 'pnio7h',
#   '7215': 'pnj7hr',
#   '7259': 'pnno5g',
#   '7263': 'pnphrp',
#   '7265': 'pnptu1',
#   '7275': 'pnqvhy',
#   '7283': 'pnqvhy',
#   '7286': 'pnqzgk',
#   '7352': 'pmombt',
#   '7378': 'pmqoes',
#   '7393': 'pmr9r2',
#   '7395': 'pmr9r2',
#   '7407': 'pmrqco',
#   '7411': 'pmsu7j',
#   '7414': 'pmsu7j',
#   '7415': 'pmtrwu',
#   '7431': 'pmuxks',
#   '7432': 'pmuxks',
#   '7437': 'pmvo24',
#   '7449': 'pmw8ws',
#   '7451': 'pmwy3y',
#   '7460': 'pmzz1j',
#   '7461': 'pmzz1j',
#   '7466': 'pn1d3t',
#   '7470': 'pn1d3t',
#   '7472': 'pn1gc2',
#   '7481': 'pn1h4b',
#   '7502': 'pn2kui',
#   '7508': 'pn38hd',
#   '7558': 'pn44d8',
#   '7577': 'pn44d8',
#   '7582': 'pn44d8',
#   '7591': 'pn44d8',
#   '7594': 'pn44d8',
#   '7606': 'pn44d8',
#   '7619': 'pn4qvj',
#   '7628': 'pn5cnu',
#   '7633': 'pn7nsy',
#   '7640': 'pm1qpt',
#   '7643': 'pm1qpt',
#   '7661': 'pm2mtk',
#   '7671': 'pm4lrg',
#   '7685': 'pm4qz7',
#   '7689': 'pm4w8p',
#   '7691': 'pm4w8p',
#   '7704': 'pm666u',
#   '7707': 'pm7t97',
#   '7708': 'pm7t97',
#   '7732': 'pm81q7',
#   '7745': 'pm8eyp',
#   '7764': 'pm9o27',
#   '7788': 'pmaazd',
#   '7791': 'pmaazd',
#   '7797': 'pmaazd',
#   '7801': 'pmanhw',
#   '7808': 'pmcdmu',
#   '7825': 'pmftio',
#   '7827': 'pmftio',
#   '7843': 'pmiclw',
#   '7859': 'pmkrxc',
#   '7861': 'pmkrxc',
#   '7863': 'ple7x9',
#   '7870': 'plezb0',
#   '7875': 'plg5gy',
#   '7876': 'plg5gy',
#   '7879': 'plg5gy',
#   '7886': 'plgdo2',
#   '7896': 'plj5dj',
#   '7912': 'pllsbu',
#   '7917': 'pllu81',
#   '7924': 'plmhd9',
#   '7928': 'plmhd9',
#   '7940': 'plq3g1',
#   '7950': 'plq822',
#   '7982': 'pltgtf',
#   '7999': 'pltzdm',
#   '8000': 'plu3y1',
#   '8023': 'plvvt8',
#   '8041': 'plxw6u',
#   '8042': 'plxw6u',
#   '8046': 'plxw6u',
#   '8049': 'plxwak',
#   '8074': 'plzb46',
#   '8097': 'plzzs7',
#   '8102': 'pks68r',
#   '8107': 'pks68r',
#   '8109': 'pks68r',
#   '8110': 'pksf8h',
#   '8118': 'pkswcg',
#   '8140': 'pkvsdp',
#   '8148': 'pkvsdp',
#   '8149': 'pkw8ai',
#   '8154': 'pkw8ai',
#   '8157': 'pkw8ai',
#   '8169': 'pkwi74',
#   '8172': 'pkwk39',
#   '8178': 'pkwk39',
#   '8187': 'pkzlaf',
#   '8189': 'pkzlaf',
#   '8208': 'pl1u39',
#   '8216': 'pl1u39',
#   '8221': 'pl2ko9',
#   '8222': 'pl2ko9',
#   '8231': 'pl2mb6',
#   '8237': 'pl2mb6',
#   '8239': 'pl2mb6',
#   '8249': 'pl2z3a',
#   '8252': 'pl2z3a',
#   '8262': 'pl2z3a',
#   '8266': 'pl3bgz',
#   '8271': 'pl5h0a',
#   '8283': 'pl79fp',
#   '8284': 'pl79fp',
#   '8285': 'pl79fp',
#   '8288': 'pl79fp',
#   '8289': 'pl79fp',
#   '8290': 'pl79fp',
#   '8292': 'pl79fp',
#   '8295': 'pl79fp',
#   '8297': 'pl79fp',
#   '8318': 'pl9qpc',
#   '8345': 'plb3nw',
#   '8349': 'plbcdm',
#   '8362': 'plc00a',
#   '8369': 'plc00a',
#   '8441': 'pld5el',
#   '8449': 'pk3wjs',
#   '8452': 'pk3wjs',
#   '8460': 'pk68uj',
#   '8464': 'pk72qa',
#   '8467': 'pk7uac',
#   '8480': 'pk9ahy',
#   '8485': 'pk9fn7',
#   '8506': 'pkbtka',
#   '8508': 'pkbtka',
#   '8528': 'pkezg3',
#   '8532': 'pkezg3',
#   '8534': 'pkezg3',
#   '8535': 'pkezg3',
#   '8542': 'pkhknx',
#   '8558': 'pkhknx',
#   '8559': 'pkhknx',
#   '8562': 'pkhvc9',
#   '8563': 'pkhvc9',
#   '8570': 'pklq3r',
#   '8583': 'pkoc56',
#   '8589': 'pkodur',
#   '8608': 'pjfl93',
#   '8621': 'pjj9kk',
#   '8625': 'pjkgnx',
#   '8628': 'pjkgnx',
#   '8636': 'pjkx0x',
#   '8645': 'pjkx0x',
#   '8646': 'pjkx0x',
#   '8653': 'pjkx0x',
#   '8689': 'pjmkr6',
#   '8707': 'pjo2ym',
#   '8710': 'pjo2ym',
#   '8717': 'pjp4kc',
#   '8774': 'pjpt7o',
#   '8836': 'pjwj23',
#   '8847': 'pjxzdf',
#   '8849': 'pjxzdf',
#   '8856': 'pjyxk5',
#   '8859': 'pjz5ab',
#   '8867': 'pjzbyv',
#   '8870': 'pjzh27',
#   '8880': 'pk0bvx',
#   '8895': 'pk1wco',
#   '8907': 'pk1z6d',
#   '8915': 'pk1z6d',
#   '8930': 'pis4k9',
#   '8945': 'pitnwj',
#   '8976': 'piwwyv',
#   '8980': 'piwwyv',
#   '8989': 'pixape',
#   '8998': 'pixf3p',
#   '9015': 'piydof',
#   '9018': 'piydof',
#   '9025': 'pj098w',
#   '9026': 'pj2x13',
#   '9029': 'pj2x13',
#   '9035': 'pj3cms',
#   '9040': 'pj3ws8',
#   '9075': 'pj5kb6',
#   '9076': 'pj62gk',
#   '9082': 'pj62gk',
#   '9084': 'pj62gk',
#   '9091': 'pj62gk',
#   '9093': 'pj8ihq',
#   '9094': 'pj8ihq',
#   '9095': 'pj8ihq',
#   '9119': 'pjbhl1',
#   '9121': 'pjbhl1',
#   '9123': 'pjbhl1',
#   '9128': 'pjbhl1',
#   '9135': 'pjbhl1',
#   '9150': 'pjbhl1',
#   '9160': 'pjbhl1',
#   '9162': 'pjbhl1',
#   '9174': 'pjbhl1',
#   '9200': 'pjdmmd',
#   '9214': 'pi6vh7',
#   '9216': 'pi6vh7',
#   '9234': 'pi6vh7',
#   '9238': 'pi6vh7',
#   '9243': 'pi6vh7',
#   '9300': 'pidu4d',
#   '9306': 'pidu4d',
#   '9308': 'pigz81',
#   '9311': 'pigz81',
#   '9318': 'pijeav',
#   '9321': 'pijeav',
#   '9327': 'pijeav',
#   '9331': 'pikjqe',
#   '9333': 'pikjqe',
#   '9345': 'pilfv3',
#   '9352': 'pim0or',
#   '9353': 'pim0or',
#   '9393': 'pimhty',
#   '9398': 'pimkf6',
#   '9418': 'pio71u',
#   '9436': 'piptu9',
#   '9455': 'piqe70',
#   '9473': 'phkucx',
#   '9492': 'phkucx',
#   '9495': 'phkucx',
#   '9496': 'phkucx',
#   '9499': 'phkucx',
#   ...},
#  'text': {'20': 'i don t have much experience with pg solutions  but the ones i do have say shake well before use  do certain chemicals not fully dissolve in pg  in this case the chemical was etiz    \n\ni ve been dosing ethanol solutions multiple times daily and it s starting to hurt my sublingual areas  so i figure i double up on my ethanol solution so i don t have to use some many drops to reach my dose or dilute my ethanol solution with pg \n\ndoes anyone else sublingual everyday  how did you attack the problem  does pg and    ethanol even mix together well \n\ni did use the search engine  so far i ve just doubled up on my diclazepam so i don t have to take so many drops  but considering diluting the ethanol with pg  has anyone found the perfect ratio ',
#   '28': '  mph    flouromethylphenidate   while not having the short duration or numbing effects  has been studied as an anti cocain medication  here s what wikipedia has to say about it  \n           \n   fluoromethylphenidate was studied further along with other analogues of  ±  threo methylphenidate  tmp  to assess their potential as anti cocaine medications    mph was reported as having an   mg kg of         –      regarding its efficacy as a substitute for cocaine  and a relative potency of     compared to methylphenidate for the same purpose  this is based on its binding strength to the dopamine transporter vs  its activity as a dopamine reuptake inhibitor  in theory  this would block some of the effects of cocaine  without being as addictive    \n\ni have been dealing with add my whole life  and i was prescribed methylphenidate in high school  but i absolutely hated it  so i stopped taking it and used small doses of cannabis to help with my add  and my grades shot up  fast forward to   and i decided to try   mph after reading some good things about it  basically it s more recreational and lacks most of the negative side effects  namely it doesn t cause ticks for me like ritalin did  and it doesn t  steal my personality   which us what my friends all said methylphenidate did   and found it to be my favorite stim  i ve always been more of a downers person anyways  but i ve done my fair share of stims over the last   years or so  but i ve always hated coke  don t know why   i m just weird i guess ',
#   '34': 'it seems like an accurate name for what it is  best practices to reduce the chance of causing harm  \n\ni can see how the name might seem to imply that there is always   some   harm and drug users should try to reduce it  but that s just semantics \n\nit could be called  safety promotion  or something like that to have a more positive spin  but i don t think it s a good idea to sound like we are encouraging people to use drugs  because at the end of the day it very much   is   possible for drugs to cause physical mental emotional harm to people if they are not careful  \n\nso again we come back to harm reduction',
#   '35': 'i think as it stands now people take the definition of harm reduction and bend it to their needs  i think  just don t do it  is perfectly reasonable harm reduction advice but i ve seen people get harassed for suggesting it  there are plenty of scenarios where its smarter to just forgo whatever drug you were going to do because the risk outweighs the reward \n\nthat said   harm reduction  advice is crucial because people are going to do it no matter what  but sometimes the right answer is to just listen to the guy that says  don t take  x   it s a bad idea and here s why  ',
#   '39': 'i ve started to have some pretty hot takes on dr  carl hart  ok  not that hot  i actually still like him  just starting to think about things a little differently  i agree with what he actually promotes  which is the complete decriminalization of drugs  as well as to end the social stigma surrounding drug use and addiction  these are both really good goals  but the more i ve read  the more i ve realized that he s pretty bias when it comes to the actual science  he tends to only lead with  and speak loudly about  research that supports his views  i started to notice this when i read some of his peers who  although they agreed with his philosophy about drugs  believed he was playing fast and loose with the science  idk i m an idiot though  i found it pretty convincing and now i guess i got my doubts or something    \n\n\nunless every single recreational drug user goes out tomorrow and gets a degree in pharmacology  or whatever it would take for them to understand the drugs they take completely  there will be risk and harm associated with drug use  that s because at a very basic level  most of us who take drugs don t have the educational background to know everything about what we re taking  it s common sense to consult a doctor before starting a medication  but when you re regularly iving drugs that weren t produced in sterile environments  or plugging pills or whatever the fuck  you open your body up to some really serious side effects ',
#   '43': 'i like it alright  it seems to be around twice the potency of concerta  i only take it maybe once a month or so when i need it  just happened to take some today  \n\nmy experience today \n\n     oral in a cap  \n   effects are obvious by the point  seems to make me slightly more verbally affluent  a little more outgoing\n   this is probably about when it peaked  \n   definitely coming down by this point  feel hungry for the first time today  notice some thirst at that point too  \n   feeling closer to baseline  no fatigue  but definitely hungry now  \n   take about    with food this time  drink two bottles of water  \n   second peak  food  no thanks  thirsty again  great time to do some chores  \n\nstill haven t come down completely from the second dose yet  seems to last about   hours for me  worth noting i m not a small guy  i m about       and do amateur bodybuilding  no real tolerance because i avoid hard stims  only get caffeine from my pre workout ',
#   '45': 'im on a methylphenidate subscription  take     per day  i don t really feel any peaks or comedown from that  just helps me function \n\ni tried   for the first time today     mainly because i read that it doesnt suppress ur appetite as much  for me it works exactly the same as methylphenidate but i have very bad add so i kinda figured it would \n\nhelps me function so for focus and stuff it definitely works but i could imagine people getting very speedy on it  some of my friends ask me for my meds if they need to study or something and they go completely wild on like   haha  even have friends that take it to parties and stuff  it s so weird to realize  \n\ni prefer methylphenidate because of the length  i redose when i want  i do want to mention that my appetite \n was better today  actually ate breakfast and was hungry throughout the day  never tried concerta so can t comment on that  \n\nstill if u have adhd add it s a matter of pro s and cons in terms of meds  i wish to be off them one day but i am a complete mess off them  the lack appetite and insomnia suck alot though  methylphenidate makes me very good at doing tasks and definitely changed my life for the better but does make me a less social person  i feel like  \n\nthe thing i ve learned is that you should not just consider the meds as a tool to function  also view it as a tool to be conscious of your disorder and try work on it  be aware of your mind and how it works  working out and meditation works wonders too  \n\njust give it a shot op  try and see how it works  if you have adhd it won t be any different i think  but it might work for the appetite ',
#   '54': 'honestly    is entirely different beast from both lsd and mushrooms  if you like stimulants  like mdma  you should be okay on the    the whole phenethylamine family is pretty friendly and if you didn t like the dissociative effects of lsd  and the weird  otherworldlyness of mushrooms    is a very  very grounded psychedelic option in my opinion \n\none thing   the come up can suck big time  can make you quite anxious and you might have thoughts of regret during this time  but in my case these feelings quickly subside after the initially rough come up \n\ni say go for it \n\nedit  also  it is up to you and your discretion  take my advice with a grain of salt  you re asking so i m giving you the best answer i ve got  it s your decision to make  \n\nas someone else said you might try a somewhat lower dose first if you have a scale that you trust at lower than   \n\n   \n with   i ll have my gf blow me if shit goes wrong and i ll also write on my hand that i took    so that i know why things went south if i lose my memory  this should be manageable  right  \n\nnevermind man  this kind of thinking has me really worried about you  my revised advice is hang it up for a few years and try again ',
#   '55': '    enhance the emotions  when you re afraid of getting a psychosis  you will definitely get a psychosis \n\n\n\n\n  lsd can be pretty brutal    is not a starter dose    would be my recommendation \n\n\n\n\n  always make sure you are in a trusted and safe environment  plan your trip  eat healthy a week before the trip  get sleep  avoid stressful events and make sure to find some peace inside you  during the trip  don t control  let your emotions do everything  \n\n\n\n\nat this moment i would not recommend you doing any psychedelics  your unconscious  fear  of getting a psychosis will give you a bad start to begin with ',
#   '83': 'i m thinking of doing   of   next month  which is technically a very low dose of one of the most forgiving psychedelics    \n\nthe thing is that i ve had   and   of lsd and   of weak shrooms    did nothing to me   and had psychosis on all three of those  shrooms were the most manageable to me  but i couldn t control the lsd no matter how hard i tried    \n\non lsd i had absolutely no visuals that would be considered psychedelic visuals  i basically felt shit faced drunk and was not seeing things that are actually there  lots of things were missing from my vision field  i was also blacking out and my memory was wiped to nearly zero but that wasn t an ego death  i couldn t even remember that i took lsd lol    \n\nwith   i ll have my gf blow me if shit goes wrong and i ll also write on my hand that i took    so that i know why things went south if i lose my memory  this should be manageable  right ',
#   '92': 'safe  no  by the strictest measures of safety  none of these chemicals is even safe to take on their own  they re not scientifically studied well enough to make that judgement \n\nthat is  assuming the ingredients are exactly the ones on the label  without impurities  cutting agents  or solvents  that would be unlikely  but let s assume that the labels are accurate and the manufacturering was clean \n\ndopaminergic stimulants carry the risk of neurotoxicity by means of  oxidative stress  mitochondrial failure  exititotoxicity  generally that damage worsens as body temperature rises  take precautions  \n\nserotonin releasers  empathogens whatever you like to call them  can damage and or kill serotoninergic neurons  resulting in cognitive decline and long term depression  don t use too often  \n\npsychedelics will temporarily impair judgment in a dose dependant manner  this can be good or bad and some changes can be permanent  \n\ncombining these exponentially increases the risk of damage done to your brain  especially combining stims and empathogens is risky \n\nchoose wisely  you only have one brain ',
#   '95': 'hi all  what do you think of the below combinations  is it safe to mix rcs like this these were sold as a     ml liquid potions in some nl smart shops  prior to the ban of course  not sure what their status is now  under a brand name with different coloured liquids  colours achieved by using e numbers i guess    sorry not sure of the exact dose of each rc as it’s not published by the manufacturer…\n\npurple potion    mmc     cmc     apb     fa     ho met\n\npeach potion    mmc   dc tropa  whatever that is \n\ngreen potion    fa     fma     fma\n\nblue potion    mapb     mmc     lsd',
#   '99': 'don t fuck up your taper  man \n\nusing etizolam will definitely mess it up  raising the dose or using some other benzo instead will put you right back at square one \n\nyou re weaning down for a reason i d imagine  it s worth doing   etiz will make whatever lower dose you re on less effective and you ll likely have to raise the dosage to feel comfortable again   which kinda negates and progress you ve made \n\nyou can stay at the same dosage for a few days until you re comfortable lowering it again  but never raise the dosage \n\nif you re craving it  just stay at the same dosage for a few days   let your body get acclimated to the lower dose ',
#   '100': 'don’t do it  i did this during tapering phenibut  gabapentin  pregabalin  and now baclofen  overall  i’m tapering but i want to occasionally “treat” my self  and this causes kindling  so anytime you take a high dose while tapering its going to cause a glutamate storm and when it wears off it will result in increased withdrawal symptoms  its truly hell \n\nfew years of this this has resulted in me being stuck dependent on gabaergic drugs everyday off my life since i was    and always tapering one or another drug for the past   months  \n\ni’m down from   to just   baclofen a day  but i once a week use benzos and that makes the taper so slow because i get glutamate rebound \n\ndon’t be like me lmao',
#   '108': 'an interest in research chemicals comes with an aknowledgement that once really good chemicals are found  they will become more mainstream and eventually be sold on the street  and when that happens blanket bans and new charted substances ensue  it s always been this way  people that have been here for a while miss a pvp       fa    aco dmt and all this other research chems that were just perfect for what they were  but were so good that they went out of the research sphere and into the street market  these can only be found on the dnm now but for nowhere near as cheap as you used to be able to get them from legal rc laboratories as now the manufacturies are illegal manufacturers  happy travels ',
#   '118': 'i want to start off by saying i had tried this combination last week and it didnt really go that well because of my complicated living situation  but that s another story  anyways this week i had moved into a new place and decided to just take some   ho pcp initially but during the experience i had the urge to try the combo out again and ended up having one of the craziest trips of my life  i dont usually write trip reports but i found nothing online about this combo and i think it definitely deserves more attention so id like to share my experience  also id like to point out that the doses here are kind of high for this combo and you should start much lower if you decide to combine them  i have some tolerance and have a lot of experience with dissos and hallucinogens in general \n\nso i weighed up   of   ho pcp  insufflated it and just layed down as i waited  for it to hit  i got the typical numbing  loss of balance and  wooziness  i get from   ho pcp within   minutes and started to get the heavy eyes and slight itch from the opioid receptor activity and decided to throw on some music  at first i just felt really neutral towards everything i put on and was just kind of spaced out but about an hour in i peaked and the euphoria and music appreciation really started to kick in  i smoked some weed and this just became stronger and my vision became blurrier \n\nnow i was pretty dissociated  my vision had that fuzzy colorful static overlay and i was feeling really lovey and introspective  now this is a typical   ho pcp experience which i dont really feel the need go go into too much detail about as there are lots of other reports online so ill just skip up to the point where i decided to dose mxipr \n\nprobably about   or   hours into the experience i felt a sudden compulsion to dose some mxipr to give the combo another shot  i smoked another bowl and started off with   snorted  within   minutes i was already feeling the typical mxipr onset  a nos like rush and a feeling like me and everything i touched is draped in a warm silky blanket  this just became stronger and it was very enjoyable  the music appreciation somehow became even better and i just melted into the couch and felt incredibly at peace and euphoric  knowing now how good this combo felt i wanted to go deeper and judging by how strong jusr   mg was i figured it wouldn t take much more to hole  this is where things get really wild \n\ni weighed up   and snorted it  layed down and it felt like it was kicking in almost instantly so i threw on one of my favorite albums and closed my eyes  very quickly i lost the sensation of my body and started morphing into different shapes colored in dark hues of red  yellow  and shades of black  then suddenly i felt as if i was with my father who had passed away  i couldnt see him at first  it was mostly just a feeling of his presence and it was very comforting and euphoric  all i could feel was love and this strong sensation of euphoria akin to that of what nos is like on mdma  the sensations of morphing into different shapes became stronger and stronger and i started to feel like i was massive  then the size of an atom or both at the same time  which kept just enveloping me more and more \n\nall of these shapes were very round in shape  feeling very soft  silky  warm and fuzzy  it started to feel as if they were cogs and gears of an endless cosmic machine that was behind the scenes of normal sober reality causing everything that existed  i just kept changing into different parts of this  cosmic machine  and felt as if i was the entire thing but only capable of experiencing different parts at different times  at this point i had forgotten about my father or anything else in my life  i had a complete ego death and forgot about everything else  it was as if i had always been here and this was always my reality  just a cog in this giant cosmic machine  it felt really divine and holy almost  like my existence was just serving some ...
#   '149': 'i tried it recently and wasn t overwhelmed  it actually reminds me of codeine in some ways  but distinguishing opiates isn t my strong point  so overall the buzz is kind of like codeine  a little subtle but strong enough that you feel pretty social  it s also kind of stimulating  it won t make you nod at all  the part that makes it unusual is it also has a very dissociating nature as you push the dosage  apparently that s how it works as an antidepressant  modulating nmda receptors \n\nwhile i was on it i found the high to be fleeting and moreish  it d wear off just as i was sort of getting into it and i d have to redose another    overall i d get higher from a solid kratom extract for about the same amount of money \n\nedit  is that why i had a headache for the next three days ',
#   '154': 'it’s a short lived opioid high that lasts like   hours at the most and has what i’d call a nasty comedown effect where you feel like shit for awhile after you take it  \n\ni strongly discourage using tianeptine recreationally as one there’s better rc opioids to  ab use and two it’s an amazing option for those with treatment resistant depression and is also a good anxiolytic as well in therapeutic doses which is     milligrams   times a day  \n\nhowever you do you  if you decide to do it recreationally i recommend   to   milligrams of it if you have tianeptine sodium and are opioid naive  if you have tianeptine sulfate the dosage will be different ',
#   '218': 'lest we not forget  apart from the hours long masturbation fuck sessions  there is that whole occasional psychosis problem associated with that shit \n\nanecdotal but funny  i know a chick who was convinced to the point of telling a cop that she had her ex tied up in the trunk of her car   she d been pulled over  she didn t just flag down a cop to volunteer that information   he asked her to pop her trunk and wouldn t you know it  nobody in there  by that point  it occurred to her that she was either gonna get hauled off to the psych ward for being crazy or jail for a dui  so she threw her keys into a field   because apparently  you can t fix stupid  but you can make logic and reason turn into irrational and retarded  just add bath salts ',
#   '237': 'ok seriously though  i don t want to be the reason why people try this combo because it s dangerously addictive but maybe some people will understand and think twice before trying this especially if they know they have addictive personality \n\nso imagine if there s a drug that lets you masturbate and feel like you re about to come but you re not and your stuck between that finishing and now but also being in a huge bliss of orgasm  \n\nthat s what     porn   fapping can do\n\nit s the ultimate drug to prolong sex imo  and for me it s the reason why i m still addicted to this combo for almost a year and a half   using once a week for a whole night \n\nanyone else understand what im going through \n\njust be careful out there  your brain will not care sometimes about reasons why not   especially if you remember how good something felt  ',
#   '243': 'i managed to find some crucial data on lamictal  i hope it s useful  \n\n pharmacodynamics\nlamotrigine likely prevents seizures and prevents mood symptoms via stabilizing presynaptic neuronal membranes and preventing the release of excitatory neurotransmitters such as glutamate  which contribute to seizure activity \n\na note on cardiovascular effects\n\nthe metabolite of lamotrigine    n methyl metabolite  formed by glucuronidation   is reported to cause dose dependent prolongations of the pr interval  widening of the qrs complex  and at higher doses  complete av block  although this harmful metabolite is only found in trace amounts in humans  plasma concentrations may increase in conditions that cause decreased drug glucuronidation  such as liver disease\n\nthe exact mechanism of action of lamotrigine is not fully elucidated  as it may exert cellular activities that contribute to its efficacy in a range of conditions  although chemically unrelated  lamotrigine actions resemble those of phenytoin and carbamazepine  inhibiting voltage sensitive sodium channels  stabilizing neuronal membranes  thereby modulating the release of presynaptic excitatory neurotransmitters \n\nlamotrigine likely acts by inhibiting sodium currents by selective binding to the inactive sodium channel  suppressing the release of the excitatory amino acid  glutamate  the mechanism of action of lamotrigine in reducing anticonvulsant activity is likely the same in managing bipolar disorder  studies on lamotrigine have identified its binding to sodium channels in a fashion similar to local anesthetics  which could explain the demonstrated clinical benefit of lamotrigine in some neuropathic pain states \n\nlamotrigine displays binding properties to several different receptors  in laboratory binding assays  it demonstrates weak inhibitory effect on the serotonin     receptor  lamotrigine also weakly binds to adenosine     receptors      β adrenergic receptors  dopamine     receptors  gaba a b receptors  histamine   receptors  κ opioid receptor  kor   mach receptors and serotonin     receptors with an     µm  weak inhibitory effects were observed at sigma opioid receptors   an in vivo study revealed evidence that lamotrigine inhibits      r type  calcium currents  which may also contribute to its anticonvulsant effects  \n\nhttps   go drugbank com drugs  ',
#   '244': 'hydroxyzine and mirtazapine helped after doing a fairly quick emergency taper by a walk in clinic  also worked well enough to relieve excessive anxiety for me to not really want to take benzos any more  and that is coming from someone who was on them for    years  ssris  snris  etc  didn t do anything for anxiety in my experience \n\ni ve read gabapentin can go either way and for me it almost made the mild post acute withdrawal phase worse \n\nso while i haven t had the same experience as you  i have found truly better alternatives for anxiety so you could be onto something there  it might just be a matter of  distract my brain with better feelings  while it slowly resets itself back to a new baseline ',
#   '247': 'i am curious if anyone has experience with taking benzos while on lamictal  i am   lamictal a day and have been for several years  i went through about a   month period where i would take average     mg or so etiz every daily  i was concerned about withdrawals when i ran out of etiz but never experienced a single symptom of withdrawal from the etiz \n\ni did notice that benzos and gabaergic  drugs in general seem to have a reduced effect while on lamictal  leads me to believe it has some sort of mitigating effect on benzos and possibly withdrawal that could otherwise have occured  note that lamictal can be used for controlling seizure disorders  \n\njust got me thinking that maybe i ve stumbled upon an exit strategy for people struggling to taper from benzos  hop on lamictal for a couple months before quitting the benzos  of course  the lamictal itself would have to be tapered but as it holds no recreational value it would be hella easier than trying to taper benzos imo \n\nhas anyone else had this experience ',
#   '249': 'so i received five blotter tabs of   of   in the mail today  so i’ve decided that tomorrow morning i’ll take two of them and leave a report here the next day  i’ve never tried   but i am an experienced tripper  my plan for the day is to eat breakfast right after taking both tabs and watch a disney movie while i wait for the come up  or i might watch a studio ghibli film  after that i want to take a walk and just listen to music  after this i may call my friends and if not i’ll probably just try to play valerint or some thing  are there many differences between   and lsd when it comes to visuals ',
#   '272': 'hello there fine people of  r researchchemicals\n\nthis is a very awkward post for me to make  but here it goes  has anyone here that has taken   meo pcp in the     range orally had significantly shrunken testicles or other similar physical reactions  i took yesterday    in a  parachute  of   meo pcp orally and after the experience subdued to an almost sober level i noticed my testicles looked smaller and felt a bit weirder  i thought i must still be tripping  as it hit harder and than i expected to my first time many months ago   but my girlfriend when she saw me naked after taking a shower also told me that my testicles are significantly smaller than before taking the   meo pcp \n\nthank you fine people for your time ',
#   '331': 'my favorites are etizolam  flualprazolam  clonazolam and bromazolam   i also have the most experience with these   but i ve tried a few others over the years as they ve popped up at various vendors \n\n    \n\nfor daily use  not fucking me up but genuinely reducing my social anxiety  pyrazolam was great but i haven t been able to find it in probably a year or two  i tried nitrazilam  sp   a few years ago and it gave a nice body glow  very different and subtle  but worth the try  there was another one that i only saw offered that i remember calling it like cinnamon but it was cina something  that was incredible for sleep with no hangover the next day ',
#   '353': 'i would take like     of a tab tops \n\ndon’t let people tell you   is mild or a beginner trip or downplay it  people who act like that are either low responders  are ego tripping  have a tolerance and forgot how strong it is without one  or have only used street lsd  \n\nlsd is a ridiculously strong drug  an accurate   is not something to take lightly \n\noh also  i’d just swallow the tab on an empty stomach   it doesn’t make any difference in terms of come up or effects  don’t really get why sublingual is what everyone does  it’s an annoying roa and not even necessary ',
# ...
#   '4651': 'mda',
#   '4652': 'mda mdma',
#   '4654': 'ket dck mdma',
#   '4658': 'pvp benzos',
#   '4661': 'meth',
#   '4662': 'ketamine psilocybin diazepam',
#   '4666': 'ketamine psilocybin diazepam',
#   '4668': 'ketamine psilocybin diazepam',
#   '4705': 'dopamine',
#   '4706': 'mxe pvp methoxetamine ketamine meth',
#   '4708': 'mxe ket mdma dmxe',
#   '4721': 'bromazolam etizolam fluclotizolam flualprazolam clonazolam diclazepam pyrazolam alprazolam diazepam clonazepam flubromazolam benzo',
#   '4745': 'odsmt',
#   '4752': 'odsmt',
#   '4770': 'dck benzos',
#   '4795': 'dmt',
#   '4796': 'dmt',
#   '4834': 'benzos',
#   '4855': 'etizolam flualprazolam',
#   '4861': 'etizolam flualprazolam',
#   '4876': 'benzo benzos',
#   '4899': 'benzo benzos',
#   '4912': 'dck mxipr benzo ket',
#   '4930': 'dck mxipr benzo ket',
#   '4933': 'dmt',
#   '4934': 'dmt',
#   '4996': 'dmt',
#   '5019': 'mapb mdma etizolam',
#   '5031': 'mapb mdma etizolam',
#   '5033': 'pyrazolam benzo',
#   '5040': 'dsmt clonazolam',
#   '5044': 'dsmt etizolam',
#   '5048': 'dsmt etizolam',
#   '5080': 'cyclazodone',
#   '5114': 'cyclazodone',
#   '5118': 'cyclazodone',
#   '5138': 'benzos clonazolam',
#   '5152': 'fdck ketamine',
#   '5158': 'dmt dpt acetone',
#   '5164': 'dmt',
#   '5177': 'dmt',
#   '5191': 'cathinone fxe ketamine',
#   '5206': 'mdma',
#   '5225': 'mdma',
#   '5227': 'amphetamine mdma',
#   '5237': 'psilocybin dmt',
#   '5255': 'dpt dmt ketamine',
#   '5261': 'dmxe mxipr mxpr mxe ephenidine phenethylamine',
#   '5280': 'ket dmxe dck dopamine ketamine',
#   '5291': 'adderall',
#   '5297': 'adderall',
#   '5298': 'adderall',
#   '5299': 'tyrosine dopamine methamphetamine',
#   '5301': 'mdma adderall',
#   '5312': 'ketamine ket',
#   '5319': 'meth gram',
#   '5349': 'meth gram',
#   '5351': 'dopamine',
#   '5378': 'adderall',
#   '5379': 'adderall',
#   '5397': 'adderall',
#   '5399': 'ketamine dck mxpr dmxe',
#   '5401': 'ketamine',
#   '5402': 'mxe ketamine',
#   '5405': 'dck',
#   '5408': 'mxe heroin ketamine phenibut',
#   '5410': 'mdma benzos',
#   '5418': 'mdma',
#   '5420': 'methamphetamine',
#   '5423': 'methamphetamine',
#   '5427': 'meth',
#   '5428': 'dmt',
#   '5432': 'dmt',
#   '5441': 'benzo',
#   '5443': 'bromazolam benzos etizolam flualprazolam fluclotizolam pyrazolam etiz',
#   '5452': 'gram coke benzos',
#   '5455': 'coke gram',
#   '5464': 'coke gram',
#   '5465': 'coke gram',
#   '5470': 'meth',
#   '5495': 'methamphetamine',
#   '5504': 'amphetamine meth',
#   '5505': 'dipt',
#   '5512': 'dipt',
#   '5513': 'dipt',
#   '5533': 'dipt',
#   '5548': 'benzos bromazolam',
#   '5550': 'benzos',
#   '5555': 'dck',
#   '5558': 'dck',
#   '5562': 'clonazolam',
#   '5583': 'clonazolam',
#   '5587': 'benzo',
#   '5612': 'amphetamine',
#   '5624': 'gram adderall amphetamine',
#   '5625': 'gram adderall amphetamine',
#   '5637': 'dopamine',
#   '5644': 'dopamine',
#   '5645': 'mdma',
#   '5650': 'mdma',
#   '5657': 'cyclazodone',
#   '5658': 'alprazolam clonazolam',
#   '5676': 'clonazolam benzo alprazolam',
#   '5687': 'cathinone',
#   '5694': 'cathinone',
#   '5710': 'mxipr mxpr',
#   '5713': 'thc mxe ketamine',
#   '5728': 'mxe mxpr ket',
#   '5745': 'amphetamine dopamine',
#   '5754': 'hexen',
#   '5782': 'psilocybin dmt mdma mda ketamine mescaline dck heroin methamphetamine amphetamine tramadol diazepam lorazepam benzos coke',
#   '5794': 'methylphenidate lisdexamfetamine amphetamine diphenhydramine doxylamine thc tyrosine psilocybin quetiapine methallylescaline dmt etizolam phenibut phenylpiracetam mdma fasoracetam kratom',
#   '5837': 'clonazolam glycol',
#   '5844': 'dopamine adderall phenibut',
#   '5852': 'dopamine adderall phenibut',
#   '5853': 'dopamine adderall phenibut',
#   '5855': 'dopamine adderall phenibut',
#   '5863': 'mapb',
#   '5896': 'mapb',
#   '5915': 'mxe',
#   '5917': 'dmt mxe pvp mapb',
#   '5921': 'alprazolam benzo benzos',
#   '5933': 'benzo benzos mirtazapine dexamphetamine mdma amphetamine cathinone',
#   '5947': 'methylphenidate',
#   '5952': 'methylphenidate',
#   '5953': 'methylphenidate',
#   '5977': 'methylphenidate',
#   '5981': 'methylphenidate',
#   '5991': 'methylphenidate',
#   '5997': 'diazepam phenazepam benzo methylphenidate etizolam dmxe dmt esketamine dck',
#   '6003': 'adderall',
#   '6004': 'adderall',
#   '6005': 'meth',
#   '6011': 'amphetamine dopamine',
#   '6017': 'bromazepam etiz benzo',
#   '6022': 'heroin meth dopamine',
#   '6026': 'benzos',
#   '6029': 'clonazepam',
#   '6031': 'benzos',
#   '6044': 'benzos',
#   '6046': 'dopamine',
#   '6058': 'dopamine',
#   '6059': 'dopamine',
#   '6060': 'dopamine',
#   '6061': 'mxe benzo flubromazolam',
#   '6070': 'mxe benzo flubromazolam',
#   '6073': 'mxe benzo flubromazolam',
#   '6074': 'cathinone',
#   '6081': 'benzene cathinone',
#   '6088': 'diazepam etiz',
#   '6109': 'diazepam etiz',
#   '6128': 'dmt',
#   '6138': 'meth',
#   '6145': 'dmt mdma mxe',
#   '6150': 'dmt',
#   '6158': 'dmt',
#   '6162': 'diclazepam diazepam benzos benzo',
#   '6170': 'diclazepam diazepam benzos benzo',
#   '6171': 'etizolam flubromazolam bromazolam',
#   '6177': 'mapb trazodone',
#   '6180': 'mapb trazodone',
#   '6181': 'amphetamine phenethylamine mescaline',
#   '6193': 'amphetamine phenethylamine mescaline',
#   '6194': 'diclaz benzos kratom tramadol',
#   '6198': 'benzo',
#   '6200': 'benzo clonazepam',
#   '6217': 'meth clonazolam benzo',
#   '6223': 'flunitrazolam benzos bromazolam',
#   '6224': 'flunitrazolam benzos bromazolam',
#   '6227': 'benzos etiz benzo',
#   '6230': 'bromazolam benzo clonazepam',
#   '6237': 'arylcyclohexylamine',
#   '6243': 'cathinone',
#   '6250': 'cathinone',
#   '6288': 'benzos',
#   '6294': 'benzos',
#   '6304': 'pcm mxe arylcyclohexylamine dmxe',
#   '6309': 'benzos odsmt opioid',
#   '6310': 'benzos odsmt opioid',
#   '6328': 'mdma mapb amphetamine',
#   '6338': 'benzo benzos',
#   '6339': 'etizolam',
#   '6343': 'etizolam',
#   '6344': 'mdma dopamine',
#   '6362': 'gram',
#   '6368': 'dsmt odsmt',
#   '6369': 'amphetamine benzene mdma',
#   '6383': 'flubromazolam clonazolam',
#   '6389': 'benzo gram etiz glycol',
#   '6390': 'diclaz benzo benzos lorazepam',
#   '6398': 'ethyl dpt dipt tryptamine',
#   '6427': 'ethyl dpt dipt tryptamine',
#   '6432': 'dopamine',
#   '6436': 'dopamine',
#   '6452': 'amphetamine gram hexen coke',
#   '6454': 'hexen benzos coke gram',
#   '6474': 'hexen benzos coke gram',
#   '6477': 'methylphenidate',
#   '6494': 'pvp coke',
#   '6501': 'flualprazolam benzos diclaz gram etiz klonopin alprazolam lorazepam clonazepam benzo',
#   '6515': 'cathinone dopamine ethyl',
#   '6522': 'dmxe mxe',
#   '6530': 'benzos alprazolam etizolam xan etiz',
#   '6535': 'benzos alprazolam etizolam xan etiz',
#   '6538': 'benzos alprazolam etizolam xan etiz',
#   '6540': 'benzos alprazolam etizolam xan etiz',
#   '6543': 'opioid kratom',
#   '6552': 'opioid kratom',
#   '6560': 'opioid kratom',
#   '6563': 'opioid kratom',
#   '6567': 'thc dmxe dck mxpr',
#   '6572': 'thc dmxe dck mxpr',
#   '6575': 'etizolam meth thc',
#   '6595': 'mapb',
#   '6603': 'mapb',
#   '6605': 'amphetamine',
#   '6612': 'tryptamine dmt coke',
#   '6618': 'clonazolam benzo',
#   '6623': 'clonazolam benzo',
#   '6624': 'ethyl',
#   '6626': 'mdma adderall',
#   '6627': 'gram',
#   '6634': 'gram',
#   '6637': 'mdma mda',
#   '6642': 'gram',
#   '6658': 'amphetamine dextroamphetamine methamphetamine meth',
#   '6677': 'amphetamine dextroamphetamine methamphetamine meth',
#   '6682': 'cannabinoid',
#   '6686': 'meth',
#   '6698': 'meth',
#   '6699': 'meth',
#   '6724': 'mapb adderall gram',
#   '6731': 'gram',
#   '6791': 'clonazepam benzos clonazolam bromazolam etizolam',
#   '6792': 'bromazepam benzo bromazolam alprazolam flualprazolam benzos',
#   '6797': 'benzos benzo bromazolam flualprazolam etizolam etiz',
#   '6805': 'rilmazafone etizolam norflurazepam bromazolam benzo',
#   '6828': 'dmt',
#   '6833': 'dmt',
#   '6851': 'dck',
#   '6861': 'dck',
#   '6875': 'clonazolam flubromazolam',
#   '6882': 'mescaline',
#   '6951': 'hexen',
#   '6988': 'benzos',
#   '7003': 'odsmt',
#   '7005': 'bromazolam benzo bretazenil',
#   '7008': 'etizolam benzo ethanol diazepam fluclotizolam bromazolam alprazolam clonazolam',
#   '7012': 'benzo benzos',
#   '7013': 'benzo benzos',
#   '7023': 'coke heroin benzos lorazepam',
#   '7027': 'benzos phenibut',
#   '7035': 'benzo etiz',
#   '7037': 'benzos',
#   '7038': 'klonopin lorazepam etizolam',
#   '7046': 'etizolam glycol',
#   '7049': 'trazodone thc',
#   '7057': 'benzo',
#   '7069': 'benzo',
#   '7078': 'benzo',
#   '7087': 'clonazolam',
#   '7091': 'benzo',
#   '7098': 'benzo',
#   '7116': 'benzos',
#   '7143': 'mxe dmt mda',
#   '7170': 'pvp mxe',
#   '7180': 'mdma mescaline',
#   '7192': 'mdma mescaline',
#   '7211': 'benzos pyrazolam benzo',
#   '7215': 'norflurazepam benzos odsmt acetone',
#   '7259': 'norflurazepam benzos odsmt acetone',
#   '7263': 'phenidate methylphenidate ethylphenidate',
#   '7265': 'etizolam benzodiazepine lorazepam',
#   '7275': 'meth',
#   '7283': 'meth dextroamphetamine coke amphetamine morphin benzo alprazolam gram',
#   '7286': 'mdma',
#   '7352': 'mdma',
#   '7378': 'ethylphenidate methylphenidate',
#   '7393': 'gram',
#   '7395': 'gram',
#   '7407': 'phenibut benzo bromazolam',
#   '7411': 'ethanol hydrochloride mxe dmxe',
#   '7414': 'dmxe ethanol',
#   '7415': 'mapb mda mdma',
#   '7431': 'mapb mda mdma',
#   '7432': 'mapb mda mdma',
#   '7437': 'amphetamine',
#   '7449': 'alprazolam benzos',
#   '7451': 'tryptamine mapb dmt mxipr',
#   '7460': 'odsmt oxy opioid acetone',
#   '7461': 'clonazolam kratom dsmt heroin',
#   '7466': 'clonazolam kratom dsmt heroin',
#   '7470': 'clonazolam kratom dsmt heroin',
#   '7472': 'tramadol dsmt clonazolam phenibut',
#   '7481': 'tramadol dsmt clonazolam phenibut',
#   '7502': 'tryptamine ketamine amphetamine coke',
#   '7508': 'ket benzo ketamine',
#   '7558': 'benzos',
#   '7577': 'benzos benzo klonopin clonazolam etizolam dopamine',
#   '7582': 'benzos benzo klonopin clonazolam etizolam dopamine',
#   '7591': 'benzos benzo klonopin clonazolam etizolam dopamine',
#   '7594': 'etizolam clonazepam',
#   '7606': 'benzos klonopin',
#   '7619': 'benzos klonopin',
#   '7628': 'mdma coke',
#   '7633': 'mdma coke',
#   '7640': 'mda',
#   '7643': 'mda mdma',
#   '7661': 'mda mdma',
#   '7671': 'mda mdma',
#   '7685': 'benzos bromazolam fluclotizolam flualprazolam clonazolam benzo',
#   '7689': 'benzos bromazolam fluclotizolam flualprazolam clonazolam benzo',
#   '7691': 'amphetamine',
#   '7704': 'amphetamine',
#   '7707': 'amphetamine',
#   '7708': 'glycol',
#   '7732': 'etiz',
#   '7745': 'etiz',
#   '7764': 'benzos etizolam',
#   '7788': 'benzos etizolam',
#   '7791': 'benzos etizolam',
#   '7797': 'benzos etizolam',
#   '7801': 'benzos etizolam',
#   '7808': 'kratom thc mdma',
#   '7825': 'acetone',
#   '7827': 'acetone dmt gram',
#   '7843': 'coke meth mdma benzo',
#   '7859': 'diazepam benzo',
#   '7861': 'benzos',
#   '7863': 'benzos',
#   '7870': 'benzos',
#   '7875': 'benzos',
#   '7876': 'benzos etizolam benzo',
#   '7879': 'gabapentin flualprazolam benzos',
#   '7886': 'etizolam',
#   '7896': 'dopamin methylphenidate tyrosine',
#   '7912': 'adderall',
#   '7917': 'adderall',
#   '7924': 'mdma',
#   '7928': 'mdma',
#   '7940': 'mdma',
#   '7950': 'gram',
#   '7982': 'fluclotizolam etizolam benzodiazepine diazepine etiz',
#   '7999': 'tryptamine dmt mdma',
#   '8000': 'mdma',
#   '8023': 'cathinone benzos bromazolam etiz benzo',
#   '8041': 'benzos',
#   '8042': 'ethanol benzos phenibut',
#   '8046': 'meth heroin kratom',
#   '8049': 'methylphenidate coke',
#   '8074': 'etizolam flualprazolam benzos pyrazolam alprazolam',
#   '8097': 'etizolam flualprazolam benzos pyrazolam alprazolam',
#   '8102': 'etizolam flualprazolam benzos pyrazolam alprazolam',
#   '8107': 'etizolam flualprazolam benzos pyrazolam alprazolam',
#   '8109': 'phenethylamine',
#   '8110': 'phenazepam flubromazolam benzos',
#   '8118': 'bromazolam pyrazolam',
#   '8140': 'bromazolam pyrazolam',
#   '8148': 'opioid dmxe',
#   '8149': 'opioid dmxe',
#   '8154': 'opioid dmxe',
#   '8157': 'kratom',
#   '8169': 'oxy',
#   '8172': 'benzo',
#   '8178': 'benzos',
#   '8187': 'benzos pyrazolam diclazepam benzo phenibut',
#   '8189': 'clonazepam benzodiazepine',
#   '8208': 'meth',
#   '8216': 'meth',
#   '8221': 'flunitrazolam benzo',
#   '8222': 'benzos etizolam bromazolam nitrazolam benzo',
#   '8231': 'benzos etizolam bromazolam nitrazolam benzo',
#   '8237': 'benzos etizolam bromazolam nitrazolam benzo',
#   '8239': 'benzos etizolam bromazolam nitrazolam benzo',
#   '8249': 'ketamine',
#   '8252': 'ketamine dck ket mdma dmt',
#   '8262': 'dck ketamine dmxe mapb mdma dmt benzos',
#   '8266': 'flunitrazolam clonazolam benzos alprazolam clonazepam',
#   '8271': 'clonazolam coke',
#   '8283': 'clonazolam coke',
#   '8284': 'amphetamine',
#   '8285': 'benzos',
#   '8288': 'benzo',
#   '8289': 'heroin benzos',
#   '8290': 'heroin benzos',
#   '8292': 'heroin benzos',
#   '8295': 'gram',
#   '8297': 'dmt',
#   '8318': 'odsmt',
#   '8345': 'mxe ket ketamine',
#   '8349': 'benzos',
#   '8362': 'dmt ket',
#   '8369': 'dmt ket',
#   '8441': 'dmt ket',
#   '8449': 'dmt ket',
#   '8452': 'dopamine amphetamine bromazolam mdma',
#   '8460': 'dopamine amphetamine bromazolam mdma',
#   '8464': 'dopamine amphetamine bromazolam mdma',
#   '8467': 'mdma hexen amphetamine',
#   '8480': 'benzo benzos',
#   '8485': 'mdma',
#   '8506': 'acetone clonazolam',
#   '8508': 'hexen',
#   '8528': 'benzo diclaz gabapentin',
#   '8532': 'benzos diazepam benzo',
#   '8534': 'amphetamine adderall benzo kpin benzos',
#   '8535': 'benzo isopropylphenidate benzos etizolam pyrazolam diclazepam fluclotizolam clonazepam bromazolam',
#   '8542': 'benzo isopropylphenidate benzos etizolam pyrazolam diclazepam fluclotizolam clonazepam bromazolam',
#   '8558': 'benzo isopropylphenidate benzos etizolam pyrazolam diclazepam fluclotizolam clonazepam bromazolam',
#   '8559': 'benzo isopropylphenidate benzos etizolam pyrazolam diclazepam fluclotizolam clonazepam bromazolam',
#   '8562': 'hexen',
#   '8563': 'hexen',
#   '8570': 'amphetamine',
#   '8583': 'amphetamine',
#   '8589': 'amphetamine',
#   '8608': 'bromazolam',
#   '8621': 'dopamine pvp meth coke',
#   '8625': 'acetone',
#   '8628': 'acetone coke',
#   '8636': 'acetone coke',
#   '8645': 'acetone coke',
#   '8646': 'acetone coke',
#   '8653': 'acetone coke',
#   '8689': 'acetone coke',
#   '8707': 'mapb mdma mda',
#   '8710': 'mapb mdma',
#   '8717': 'mapb mdma',
#   '8774': 'mapb mdma',
#   '8836': 'mapb mdma dopamine mescaline',
#   '8847': 'mapb adderall tryptamine mdma',
#   '8849': 'mapb mxipr adderall dmxe methallylescaline mdma',
#   '8856': 'benzos etizolam pyrazolam benzo diclazepam fluclotizolam clonazepam bromazolam',
#   '8859': 'benzodiazepine',
#   '8867': 'etizolam ethanol',
#   '8870': 'meth amphetamine pvp',
#   '8880': 'phenibut dopamine mapb',
#   '8895': 'phenibut dopamine mapb',
#   '8907': 'ket',
#   '8915': 'ketamine ket',
#   '8930': 'kratom dsmt tramadol',
#   '8945': 'allylescaline mescaline',
#   '8976': 'allylescaline mescaline',
#   '8980': 'dmt meth',
#   '8989': 'mda',
#   '8998': 'mda',
#   '9015': 'dipt dpt dmt',
#   '9018': 'dmt',
#   '9025': 'mdma',
#   '9026': 'adderall',
#   '9029': 'isopropylphenidate',
#   '9035': 'isopropylphenidate',
#   '9040': 'ketamin ketamine',
#   '9075': 'ketamin ketamine',
#   '9076': 'tramadol heroin',
#   '9082': 'tramadol dmt ketamine heroin',
#   '9084': 'dsmt',
#   '9091': 'odsmt dsmt',
#   '9093': 'dmt',
#   '9094': 'ethanol',
#   '9095': 'dmt glycol',
#   '9119': 'benzo etizolam etiz',
#   '9121': 'clonazepam clonazolam etizolam etiz benzo',
#   '9123': 'benzo',
#   '9128': 'clonazolam',
#   '9135': 'clonazolam',
#   '9150': 'clonazepam benzos benzo',
#   '9160': 'alprazolam clonazolam benzos bromazolam klonopin benzo',
#   '9162': 'klonopin benzos benzo flubromazolam',
#   '9174': 'klonopin clonazolam',
#   '9200': 'klonopin clonazolam',
#   '9214': 'klonopin clonazolam',
#   '9216': 'klonopin clonazolam',
#   '9234': 'benzos',
#   '9238': 'thc',
#   '9243': 'phenibut benzos clonazepam',
#   '9300': 'phenibut benzos clonazepam',
#   '9306': 'psilocybin mescaline alprazolam',
#   '9308': 'heroin',
#   '9311': 'heroin',
#   '9318': 'phenibut',
#   '9321': 'mdma',
#   '9327': 'tryptamine mdma',
#   '9331': 'diazepam',
#   '9333': 'gram diclaz klonopin',
#   '9345': 'gram diclaz klonopin',
#   '9352': 'phenibut thc mdma',
#   '9353': 'phenibut thc mdma',
#   '9393': 'phenibut thc mdma',
#   '9398': 'meth',
#   '9418': 'benzo phenibut',
#   '9436': 'fdck',
#   '9455': 'diclazepam benzos clonazepam pyrazolam',
#   '9473': 'diclazepam benzos clonazepam pyrazolam',
#   '9492': 'diclazepam benzos clonazepam pyrazolam',
#   '9495': 'mdma benzo',
#   '9496': 'heroin etizolam',
#   '9499': 'heroin etizolam',
#   ...}}

# %%
db = client.for_class

# %%
db.collection_names()
# Out:
# ['raw_data', 'cleaned_data', 'for_class.cleaned_data', 'for_class']

# %%
result=db.for_class.cleaned_data.insert_one(to_database_dict)
