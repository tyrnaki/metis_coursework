# %%
import pandas as pd

# %%
data_21_09 = pd.read_csv('202109-capitalbikeshare-tripdata.csv')
data_21_08 = pd.read_csv('202108-capitalbikeshare-tripdata.csv')
data_21_07 = pd.read_csv('202107-capitalbikeshare-tripdata.csv')
data_21_06 = pd.read_csv('202106-capitalbikeshare-tripdata.csv')
data_21_05 = pd.read_csv('202105-capitalbikeshare-tripdata.csv')
data_21_04 = pd.read_csv('202104-capitalbikeshare-tripdata.csv')
data_21_03 = pd.read_csv('202103-capitalbikeshare-tripdata.csv')
data_21_02 = pd.read_csv('202102-capitalbikeshare-tripdata.csv')
data_21_01 = pd.read_csv('202101-capitalbikeshare-tripdata.csv')
data_20_12 = pd.read_csv('202012-capitalbikeshare-tripdata.csv')
data_20_11 = pd.read_csv('202011-capitalbikeshare-tripdata.csv')
data_20_10 = pd.read_csv('202010-capitalbikeshare-tripdata.csv')
data_20_09 = pd.read_csv('202009-capitalbikeshare-tripdata.csv')
data_20_08 = pd.read_csv('202008-capitalbikeshare-tripdata.csv')
data_20_07 = pd.read_csv('202007-capitalbikeshare-tripdata.csv')
data_20_06 = pd.read_csv('202006-capitalbikeshare-tripdata.csv')
data_20_05 = pd.read_csv('202005-capitalbikeshare-tripdata.csv')
#data_20_04 = pd.read_csv('202004-capitalbikeshare-tripdata.csv')
data_20_03 = pd.read_csv('202003-capitalbikeshare-tripdata.csv')
data_20_02 = pd.read_csv('202002-capitalbikeshare-tripdata.csv')
data_20_01 = pd.read_csv('202001-capitalbikeshare-tripdata.csv')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#frames = [data_21_09, data_21_08, data_21_07, data_21_06, data_21_05, data_21_04, data_21_03, data_21_02, data_21_01,
#         data_20_12, data_20_11, data_20_10, data_20_09, data_20_09]
#combined_data = pd.concat(frames)

# %%
'''
_21_09 = data_21_09['end_station_name'].value_counts().to_frame()
_21_08 = data_21_08['end_station_name'].value_counts().to_frame()
_21_07 = data_21_07['end_station_name'].value_counts().to_frame()
_21_06 = data_21_06['end_station_name'].value_counts().to_frame()
_21_05 = data_21_05['end_station_name'].value_counts().to_frame()
_21_04 = data_21_04['end_station_name'].value_counts().to_frame()
_21_03 = data_21_03['end_station_name'].value_counts().to_frame()
_21_02 = data_21_02['end_station_name'].value_counts().to_frame()
_21_01 = data_21_01['end_station_name'].value_counts().to_frame()
_20_12 = data_20_12['end_station_name'].value_counts().to_frame()
_20_11 = data_20_11['end_station_name'].value_counts().to_frame()
_20_10 = data_20_10['end_station_name'].value_counts().to_frame()
_20_09 = data_20_09['end_station_name'].value_counts().to_frame()
_20_08 = data_20_08['end_station_name'].value_counts().to_frame()
_20_07 = data_20_07['end_station_name'].value_counts().to_frame()
_20_06 = data_20_06['end_station_name'].value_counts().to_frame()
_20_05 = data_20_05['end_station_name'].value_counts().to_frame()
#_20_04 = data_20_04['end_station_name'].value_counts().to_frame()
_20_03 = data_20_03['End station'].value_counts().to_frame()
_20_02 = data_20_02['End station'].value_counts().to_frame()
_20_01 = data_20_01['End station'].value_counts().to_frame()
'''

# %%
_21_09 = data_21_09['start_station_name'].value_counts().to_frame()
_21_08 = data_21_08['start_station_name'].value_counts().to_frame()
_21_07 = data_21_07['start_station_name'].value_counts().to_frame()
_21_06 = data_21_06['start_station_name'].value_counts().to_frame()
_21_05 = data_21_05['start_station_name'].value_counts().to_frame()
_21_04 = data_21_04['start_station_name'].value_counts().to_frame()
_21_03 = data_21_03['start_station_name'].value_counts().to_frame()
_21_02 = data_21_02['start_station_name'].value_counts().to_frame()
_21_01 = data_21_01['start_station_name'].value_counts().to_frame()
_20_12 = data_20_12['start_station_name'].value_counts().to_frame()
_20_11 = data_20_11['start_station_name'].value_counts().to_frame()
_20_10 = data_20_10['start_station_name'].value_counts().to_frame()
_20_09 = data_20_09['start_station_name'].value_counts().to_frame()
_20_08 = data_20_08['start_station_name'].value_counts().to_frame()
_20_07 = data_20_07['start_station_name'].value_counts().to_frame()
_20_06 = data_20_06['start_station_name'].value_counts().to_frame()
_20_05 = data_20_05['start_station_name'].value_counts().to_frame()
#_20_04 = data_20_04['start_station_name'].value_counts().to_frame()
_20_03 = data_20_03['Start station'].value_counts().to_frame()
_20_02 = data_20_02['Start station'].value_counts().to_frame()
_20_01 = data_20_01['Start station'].value_counts().to_frame()

# %%
_21_09

# %%
result = pd.concat([_20_01,_20_02,_20_03,_20_05,_20_06,_20_07,_20_08,_20_09,_20_10,_20_11,_20_12,
                    _21_01,_21_02,_21_03,_21_04,_21_05,_21_06,_21_07,_21_08,_21_09], axis=1)

# %%
result['stations'] = result.index

# %%
result.to_csv('rideshare_start_ride.csv', index=False)

# %%
result.columns.values[0] = "_20_01"
result.columns.values[1] = "_20_02"
result.columns.values[2] = "_20_03"
result.columns.values[3] = "_20_05"
result.columns.values[4] = "_20_06"
result.columns.values[5] = "_20_07"
result.columns.values[6] = "_20_08"
result.columns.values[7] = "_20_09"
result.columns.values[8] = "_20_10"
result.columns.values[9] = "_20_11"
result.columns.values[10] = "_20_12"
result.columns.values[11] = "_21_01"
result.columns.values[12] = "_21_02"
result.columns.values[13] = "_21_03"
result.columns.values[14] = "_21_04"
result.columns.values[15] = "_21_05"
result.columns.values[16] = "_21_06"
result.columns.values[17] = "_21_07"
result.columns.values[18] = "_21_08"
result.columns.values[19] = "_21_09"

# %%
result
# Out:
#                                      _20_01  _20_02  _20_03  _20_05  _20_06  \
# Columbus Circle / Union Station      4097.0  3391.0  2225.0   562.0   919.0
# New Hampshire Ave & T St NW          2522.0  2159.0  1710.0  1225.0  2042.0
# 14th & Irving St NW                  2372.0  1973.0  1460.0   906.0  1489.0
# 15th & P St NW                       2287.0  2110.0  1719.0  1117.0  1951.0
# 1st & M St NE                        2020.0  1735.0  1685.0  1567.0  2413.0
# ...                                     ...     ...     ...     ...     ...
# White House                             NaN     NaN     NaN     NaN     NaN
# Becontree Ln & Goldenrain Ct            NaN     NaN     NaN     NaN     NaN
# North Village and Park Garden           NaN     NaN     NaN     NaN     NaN
# Hartland Rd & Harte Pl                  NaN     NaN     NaN     NaN     NaN
# W&OD Trail bridge & N Washington St     NaN     NaN     NaN     NaN     NaN
#
# ...
